# %%
import numpy as np
import os
import pandas as pd
from pathlib import Path
from typing import List, Tuple

# %% [markdown]
# # One-stop shop for cellfinder first aid
#
# 1. Cleaning for obvious extras to "Anatomy" terms, given we want "Anatomy" to be an equivalent to "Tissue
# 2. Review terms with multiple labels assigned - set priority entity types to resolve
# 3. Remove entity types extra to ["Cell type", "Cell line", "Anatomy"~Tissue]
# 4. Write to BRAT format for use in model training/validation
# 5. Older / intitial work - initial review to investigate how equivalent "Anatomy" is to "Tissue" as an entity type

# %% [markdown]
# ### Read-in cellfinder dataframes

# %%
def crawl_directory(dir_path: str, file_type: str)-> List:
    p = Path(dir_path)
    in_files = list(p.glob(f"**/*.{file_type}"))
    if in_files == []:
        print("Path path producing error - revise. \nHint - check your file_type declaration does not contain '.'")
    return in_files

# %%
# File walk to grab all .ann from cellfinder1_brat
in_files = crawl_directory(dir_path="/Users/withers/Downloads/cellfinder1_brat/",
                           file_type="ann")

# %% [markdown]
# Clean in-files so columns are organised and more readable

# %%
def readin_df(path_to_infile: str) -> Tuple[str, pd.DataFrame]:
    """ 
    Passed .ann file, clean up string formats and return with
    PMCID/ file name for reference
    """
    df = pd.read_csv(path_to_infile, sep="\t", header=None)
    pmcid = os.path.basename(path_to_infile)[:-4]

    # Split column 1 into label, start, end
    df_col1 = pd.DataFrame(np.column_stack([x.split() for x in df[1]])).transpose()
    # Drop old column
    df = df.drop(columns=[1])
    # Append cleaned cols to original df
    df = pd.concat([df, df_col1], axis=1)
    df.columns = ["id", "term", "label", "start",  "end"]

    return pmcid, df

annotations = {}
for f in in_files:
    pmcid, res_df = readin_df(path_to_infile=f)
    annotations[pmcid] = res_df

# %% [markdown]
# ### 1. For each resulting Dataframe, remove non-compliant _"Anatomy"_ terms for use as _"Tissue"_ annotations

# %%
# Endings which do not comply with Anatomy terms referring to tissue only
# These endings tend to mean processes or cell contexts
redlist = ("genesis", "cytic", "ial", "yal")

def end_check(term: str):
    return term.endswith(redlist)

for pmcid in annotations:
    df = annotations[pmcid]
    df["redlist"] = df["term"].apply(end_check)
    before = len(df)

    to_drop = df[(df["redlist"] == True) & (df["label"] == "Anatomy")]
    df_clean = df.drop(df[(df["redlist"] == True) & (df["label"] == "Anatomy")].index)
    after = len(df_clean)

    if int(before - after) != 0:
        print(f"*** {str(before - after)} non-compliant Anatomy term(s) dropped from {pmcid} Dataframe.")
        print(", ".join(to_drop["term"].to_list()) + "\n")
    else:
        print(f"No changes to {pmcid} Dataframe\n")

    annotations[pmcid] = df
# Out:
# *** 3 non-compliant Anatomy term(s) dropped from 18162134 Dataframe.
# organogenesis, neurogenesis, embryogenesis
#
# No changes to 16316465 Dataframe
#
# *** 2 non-compliant Anatomy term(s) dropped from 17381551 Dataframe.
# myogenesis, endothelial
#
# No changes to 16672070 Dataframe
#
# *** 1 non-compliant Anatomy term(s) dropped from 17389645 Dataframe.
# embryogenesis
#
# No changes to 17288595 Dataframe
#
# *** 2 non-compliant Anatomy term(s) dropped from 16623949 Dataframe.
# myelomonocytic, endothelial
#
# *** 7 non-compliant Anatomy term(s) dropped from 15971941 Dataframe.
# endothelial, Adipocytic, paraxial, adipocytic, epithelial, Osteogenesis, Chondrocytic
#
# No changes to 18286199 Dataframe
#
# *** 3 non-compliant Anatomy term(s) dropped from 17967047 Dataframe.
# neuroepithelial, neuroepithelial, neuroepithelial

# %% [markdown]
# Write cleaned annotations to file

# %%
import glob
import shutil
import os

def write_ann(df: pd.DataFrame, output_dir: str, pmcid: str):
    # Ensure destination directory exists
    os.makedirs(output_dir, exist_ok=True)

    output_path = output_dir + f"{pmcid}.ann"
    with open(output_path, 'w', encoding='utf-8') as f:
        for _, row in df.iterrows():
            line = f"{row['id']}\t{row['label']} {row['start']} {row['end']}\t{row['term']}\n"
            f.write(line)

def copy_txt_files(source_dir: str, destination_dir: str):
    # Ensure destination directory exists
    os.makedirs(destination_dir, exist_ok=True)

    # Use glob to find all .txt files in the source directory
    txt_files = glob.glob(os.path.join(source_dir, '*.txt'))

    # Copy each file
    for file_path in txt_files:
        filename = os.path.basename(file_path)
        dest_path = os.path.join(destination_dir, filename)
        shutil.copy2(file_path, dest_path)

# %%
output_dir = "/Users/withers/Downloads/cellfinder1_brat_clean/"
for pmcid in annotations:
    df = annotations[pmcid]
    df = df.drop("redlist", axis=1)
    df = df[["id", "label", "start",  "end", "term"]]
    annotations[pmcid] = df
    write_ann(df = annotations[pmcid],
              output_dir = output_dir,
              pmcid = pmcid)

# %% [markdown]
# Finally, copy .txt files to new BRAT folder

# %%
copy_txt_files(source_dir = "/Users/withers/Downloads/cellfinder1_brat/",
               destination_dir = "/Users/withers/Downloads/cellfinder1_brat_clean/")

# %%
# File walk to grab all .ann from cellfinder1_brat_clean
in_files = crawl_directory(dir_path="/Users/withers/Downloads/cellfinder1_brat_clean/",
                           file_type="ann")

annotations = {}
for f in in_files:
    pmcid, res_df = readin_df(path_to_infile=f)
    annotations[pmcid] = res_df

# %% [markdown]
# ### 2. Check if there are overlapping annotations in cellfinder
#
# #### With the preferred_labels_mode Series, clean each full df to assign only one annotation for each term
# Precedent set as follows:
#     - First, select the preferred label by the mode of the label's occurrences
#     - Prioritise by entity type as a fall-back: CellLine > Anatomy > CellType

# %%
# Sets priority Cell line > Anatomy > Cell type
priority = ["CellLine", "Anatomy", "CellType"]

def get_mode_label(series: pd.Series)-> str:
    """Return the most frequent label in a given series"""
    modes = series.mode()
    if len(modes) > 1:

        # If there is a tie in the mode label, tie-break by priority.
        for p_label in priority:
            if p_label in modes.values: #Catch highest priority label
                return p_label

        # Else, failing a tie break, return the first mode term
        return modes.iloc[0]

    # If there is an obvious mode label, return
    return modes[0]

# Group by term, selecting one label term should more than 1 occur in the annotations
for pmcid in annotations:
    print(f"PMCID: {pmcid}")
    df = annotations[pmcid]
    preferred_labels_mode = df.groupby('term')['label'].apply(get_mode_label)

    # Add back to df
    df['preferred_label'] = df['term'].map(preferred_labels_mode)

    # Update 'label' should it not be the preferred label
    df.loc[(df['label'] != df['preferred_label']), 'label'] = df['preferred_label']
    df = df.drop(columns=["preferred_label"])

    annotations[pmcid] = df
    print(df)
# Out:
# PMCID: 18162134
#        id          term        label  start    end
# 0      T1          MST3  GeneProtein  23576  23580
# 1      T2        PRKCB1  GeneProtein  22722  22728
# 2      T3         CDC42  GeneProtein  23601  23606
# 3      T4        CTNNB1  GeneProtein  23326  23332
# 4      T5          ERK1  GeneProtein  23592  23596
# ..    ...           ...          ...    ...    ...
# 673  T674         hESCs     CellType  30060  30065
# 674  T675         ERBB3  GeneProtein  34156  34161
# 675  T676          FGF2  GeneProtein  12738  12742
# 676  T677  phospho-GSK3  GeneProtein  12748  12760
# 677  T678         Stat1  GeneProtein  21660  21665
#
# [678 rows x 5 columns]
# PMCID: 16316465
#        id                                     term        label start   end
# 0      T1                                    human      Species  3043  3048
# 1      T2                                   Oct3/4  GeneProtein  3013  3019
# 2      T3                   pluripotent population      Anatomy  1734  1756
# 3      T4                                   Oct3/4  GeneProtein  3199  3205
# 4      T5                           somatic tissue      Anatomy  1784  1798
# ..    ...                                      ...          ...   ...   ...
# 409  T411  developmental pluripotency associated 5  GeneProtein  6669  6708
# 410  T412                                Brachyury  GeneProtein  5633  5642
# 411  T413                                    human      Species  8066  8071
# 412  T414                                    PODXL  GeneProtein  8026  8031
# 413  T415                                    Nanog  GeneProtein  8072  8077
#
# [414 rows x 5 columns]
# PMCID: 17381551
#        id                             term          label  start    end
# 0      T1                       M-cadherin    GeneProtein  17672  17682
# 1      T2                           nuclei  CellComponent  31805  31811
# 2      T3                            mouse        Species  13388  13393
# 3      T4                            hESCs       CellType  17658  17663
# 4      T5                           desmin    GeneProtein  25755  25761
# ..    ...                              ...            ...    ...    ...
# 844  T846                     muscle cells       CellType   8717   8729
# 845  T847  multinucleated nascent myotubes       CellType  10112  10143
# 846  T848                             limb        Anatomy  40158  40162
# 847  T849          adult muscle stem cells       CellType   8344   8367
# 848  T850                         Myofiber        Anatomy  40697  40705
#
# [849 rows x 5 columns]
# PMCID: 16672070
#        id             term        label  start    end
# 0      T1      tumor cells     CellType  26276  26287
# 1      T2            human      Species  18623  18628
# 2      T3  teratocarcinoma      Anatomy  26996  27011
# 3      T4            GAGE7  GeneProtein  26368  26373
# 4      T5           NTera2     CellLine  11589  11595
# ..    ...              ...          ...    ...    ...
# 491  T492             BG03     CellLine  39162  39166
# 492  T493            BG01V     CellLine  39127  39132
# 493  T494             BG02     CellLine  39138  39142
# 494  T495            BG01V     CellLine  39046  39051
# 495  T496            Human      Species  18483  18488
#
# [496 rows x 5 columns]
# PMCID: 17389645
#        id                                 term        label  start    end
# 0      T1                                brain      Anatomy   8952   8957
# 1      T2                             TAL1/SCL  GeneProtein    774    782
# 2      T3    haematopoietic stem cell enhancer  GeneProtein   9133   9166
# 3      T4           human embryonic stem cells     CellType    811    837
# 4      T5  endothelial-haematopoietic enhancer  GeneProtein   9189   9224
# ..    ...                                  ...          ...    ...    ...
# 215  T216                               DNaseI  GeneProtein   9513   9519
# 216  T217                               DNaseI  GeneProtein   9539   9545
# 217  T218                                 TAL1  GeneProtein  11627  11631
# 218  T219                                mouse      Species   3509   3514
# 219  T220                            hES cells     CellType  11803  11812
#
# [220 rows x 5 columns]
# PMCID: 17288595
#        id                      term        label  start    end
# 0      T1  DNA methyltransferase 3B  GeneProtein  17363  17387
# 1      T2                       PA6     CellLine  26318  26321
# 2      T3          forkhead box O1A  GeneProtein  17571  17587
# 3      T4                       PA6     CellLine  26144  26147
# 4      T5                    Foxo1a  GeneProtein  17589  17595
# ..    ...                       ...          ...    ...    ...
# 444  T445                       En1  GeneProtein  21384  21387
# 445  T446                      Sox2  GeneProtein  21378  21382
# 446  T447                  neuronal      Anatomy  21068  21076
# 447  T448                    neural      Anatomy  11875  11881
# 448  T449                  neuronal      Anatomy  11705  11713
#
# [449 rows x 5 columns]
# PMCID: 16623949
#        id                        term        label  start    end
# 0      T1             inner cell mass      Anatomy   2664   2679
# 1      T2  Human embryonic stem cells     CellType   2321   2347
# 2      T3                   hES cells     CellType   2349   2358
# 3      T4                        CD34  GeneProtein    171    175
# 4      T5                        CD34  GeneProtein    699    703
# ..    ...                         ...          ...    ...    ...
# 885  T890                       liver      Anatomy  19558  19563
# 886  T891                  Lentiviral      Species  19765  19775
# 887  T892               hematopoietic      Anatomy  23937  23950
# 888  T893                        CD34  GeneProtein  19522  19526
# 889  T894                        bFGF  GeneProtein   7783   7787
#
# [890 rows x 5 columns]
# PMCID: 15971941
#        id                    term     label  start    end
# 0      T1       paraxial mesoderm   Anatomy   2553   2570
# 1      T2                mesoderm   Anatomy   2562   2570
# 2      T3      connective tissues   Anatomy   1841   1859
# 3      T4  mesenchymal precursors  CellType   2448   2470
# 4      T5                  dermis   Anatomy   1824   1830
# ..    ...                     ...       ...    ...    ...
# 440  T455                foreskin   Anatomy  13133  13141
# 441  T456              adipocytic  CellType  13228  13238
# 442  T457             hESMPC-H1.1  CellLine   4419   4430
# 443  T458            Chondrocytic  CellType   4137   4149
# 444   T14            Chondrocytic  CellType   4137   4149
#
# [445 rows x 5 columns]
# PMCID: 18286199
#        id    term        label  start    end
# 0      T1   human      Species  24042  24047
# 1      T2   derma      Anatomy  18639  18644
# 2      T3   hESCs     CellType    194    199
# 3      T4   human      Species    309    314
# 4      T5  neural      Anatomy    315    321
# ..    ...     ...          ...    ...    ...
# 547  T552   N-CAM  GeneProtein  37092  37097
# 548  T553   hNSCs     CellType  25253  25258
# 549  T554    NF-M  GeneProtein  37107  37111
# 550  T555    bFGF  GeneProtein  21802  21806
# 551  T556   RNase  GeneProtein  35807  35812
#
# [552 rows x 5 columns]
# PMCID: 17967047
#        id                                 term        label  start    end
# 0      T1                                mouse      Species  53977  53982
# 1      T2                            hCNS-SCns     CellType  12325  12334
# 2      T3                                  rat      Species  53968  53971
# 3      T4                              Cyt-hES     CellLine  38318  38325
# 4      T5                            hCNS-SCns     CellType  11966  11975
# ..    ...                                  ...          ...    ...    ...
# 900  T901                                hESCs     CellType  57407  57412
# 901  T902  brain-specific splicing factor Nova  GeneProtein   6943   6978
# 902  T903                                  NPs     CellType  57428  57431
# 903  T904                              ES cell     CellType  11114  11121
# 904  T905                                HUES6     CellLine  36529  36534
#
# [905 rows x 5 columns]

# %% [markdown]
# Sanity check that the resolutions above have worked

# %%
# Group the terms by their labels, filtering for those with more than 1 label assigned
sanity_check = True
for pmcid in annotations:
    df = annotations[pmcid]
    df_grouped = df.groupby("term")["label"].unique()
    multiple_types = df_grouped[df_grouped.apply(len) > 1]
    if len(multiple_types) != 0:
        sanity_check = False
    
if sanity_check:
    print("Yay! All clashes resolved")
# Out:
# Yay! All clashes resolved

# %% [markdown]
# ### 3. Drop annotations of entity types extra to those required

# %%
# Remove entity types extra to ["Cell type", "Cell line", "Anatomy"~Tissue]

for pmcid in annotations:
    df = annotations[pmcid]
    df_select = df[df["label"].isin(priority)]
    print(f"Cleaned df of length {len(df)} to {len(df_select)} rows")
    annotations[pmcid] = df_select
# Out:
# Cleaned df of length 678 to 148 rows
# Cleaned df of length 414 to 161 rows
# Cleaned df of length 849 to 619 rows
# Cleaned df of length 496 to 368 rows
# Cleaned df of length 220 to 80 rows
# Cleaned df of length 449 to 217 rows
# Cleaned df of length 890 to 570 rows
# Cleaned df of length 445 to 327 rows
# Cleaned df of length 552 to 339 rows
# Cleaned df of length 905 to 634 rows

# %% [markdown]
# ### 4. Write out filtered files to BRAT format for use in model training/validation

# %%
output_dir = "/Users/withers/Downloads/cellfinder1_brat_clean_07/"
for pmcid in annotations:
    df = annotations[pmcid]
    df = df[["id", "label", "start",  "end", "term"]]
    write_ann(df = annotations[pmcid],
              output_dir = output_dir,
              pmcid = pmcid)
print(f"Annotations written to file at: '{output_dir}'")

copy_txt_files(source_dir = "/Users/withers/Downloads/cellfinder1_brat/",
               destination_dir = "/Users/withers/Downloads/cellfinder1_brat_clean_07/")
# Out:
# Annotations written to file at: '/Users/withers/Downloads/cellfinder1_brat_clean_07/'

# %% [markdown]
# ### 5. OLD/INITIAL WORKS | View the Tissue coverage of cellfinder terms by dictionaries
#
# ##### First concatentate the dictionaries used in labelstudio

# %%
# for pmcid in annotations:
#     with open(f"/Users/withers/Downloads/cellfinder1_brat/{pmcid}.txt", "r") as f:
#         input_text = f.readlines()
#     f.close()
# print(type(input_text))
# [print(x,"\n") for x in input_text]

# %%
tissue_df = "/Users/withers/GitProjects/OTAR3088/DataFolder/Data-Extraction-Query/tissue_df.tsv"
btissue_df = "/Users/withers/GitProjects/OTAR3088/DataFolder/Data-Extraction-Query/brendatissue_df.tsv"

tissue = pd.read_csv(tissue_df, sep="\t", header=None)[2].to_list()
btissue = pd.read_csv(btissue_df, sep="\t", header=None)[2].to_list()
tissue.extend(btissue)
tissue = [x.lower() for x in tissue]
tissue = list(set(tissue))
tissue
# Out:
# ['choroid plexus',
#  'eye',
#  'red nucleus',
#  'nail',
#  'corpus callosum',
#  'globus pallidus',
#  'capillary',
#  'gastrula stage',
#  'dentine',
#  'neoplasm',
#  'blood/esophagus',
#  'pancreas/plasma',
#  'ovarian follicle',
#  'anterior visceral endoderm',
#  'blood brain barrier',
#  'blood vessel endothelium',
#  'blood vessel',
#  'endothelial tube',
#  'bile/plasma',
#  'cardiac muscle fiber',
#  'caudal fin',
#  'epiphysis',
#  'whole body',
#  'large intestine/muscle',
#  'embryo sac',
#  'arm',
#  'esophagus muscularis mucosa',
#  'cyst',
#  'tooth enamel',
#  'crest',
#  'adipose tissue',
#  'renal glomerulus',
#  'gill',
#  'corpus luteum',
#  'peripheral nervous system',
#  'trigeminal ganglion',
#  'visceral fat',
#  'del',
#  'colonic mucosa',
#  'ovary/plasma',
#  'cornea',
#  'dorsal raphe nucleus',
#  'intermediate filament',
#  'lymph sac',
#  'allantoic fluid',
#  'microfilament',
#  'iris',
#  'blood plasma',
#  'alveolar wall',
#  'atrium/ileum',
#  'stria terminalis',
#  'anterior commissure',
#  'stomach',
#  'feces',
#  'urethra',
#  'hypogastric nerve',
#  'blood/heart',
#  'ileum/plasma',
#  'spicule',
#  'tibia',
#  'bladder',
#  'kidney/liver',
#  'tumor/blood',
#  'tumor/jejunum',
#  'respiratory epithelium',
#  'popliteal lymph node',
#  'imaginal disc',
#  'prefrontal cortex',
#  'coronary sinus',
#  'renal proximal tubule',
#  'rhomboidal nucleus',
#  'substantia nigra',
#  'blastula',
#  'joint',
#  'caudate nucleus',
#  'tegmentum',
#  'mole',
#  'subfornical organ',
#  'prostate gland/serum',
#  'bone',
#  'conceptus',
#  'zone of skin',
#  'breast',
#  'lumbar vertebra',
#  'ileum/liver',
#  'anterior midgut',
#  'rumen',
#  'hair follicle',
#  'skeleton',
#  'limb bud',
#  'organ',
#  'gastric juice',
#  'heart right ventricle',
#  'blood/prostate',
#  'shoot',
#  'conjunctiva',
#  'chorioallantoic membrane',
#  'hypophysis',
#  'temporal lobe',
#  'endometrial gland',
#  'hip bone',
#  'spiral modiolar artery',
#  'bloodstream form',
#  'nerve fiber',
#  'aortic endothelium',
#  'pharyngeal muscle',
#  'lower jaw region',
#  'duct',
#  'urinary bladder smooth muscle',
#  'abdomen',
#  'muscle fibre',
#  'right eye',
#  'meynerts basal nucleus',
#  'lip epithelium',
#  'coelomic fluid',
#  'uterus/plasma',
#  'gracilis',
#  'surface of epithelium',
#  'osteoid',
#  'sweat gland',
#  'duodenum',
#  'rectus abdominis muscle',
#  'fore-stomach',
#  'brain white matter',
#  'large intestine/plasma',
#  'white matter',
#  'spinal cord/plasma',
#  'intestine/plasma',
#  'gastrocnemius',
#  'caudal artery',
#  'myometrium',
#  'pharynx',
#  'blood/brain',
#  'crop',
#  'hypothalamus/serum',
#  'rhombomere',
#  'ovary',
#  'renal tubule',
#  'digestive tract',
#  'pharyngeal arch artery',
#  'eye/brain',
#  'bone/serum',
#  'esophagus',
#  'neural retina',
#  'jugular vein',
#  'pylorus',
#  'skeletal muscle tissue',
#  'sac',
#  'embryonic axis',
#  'nucleus preopticus',
#  'antral follicle',
#  'fallopian tube',
#  'tooth',
#  'lung epithelium',
#  'midbrain/caudate',
#  'taenia coli',
#  'jaw region',
#  'ileocecum',
#  'throat',
#  'eyelid',
#  'capsule',
#  'arterial endothelium',
#  'carcass',
#  'hypodermis',
#  'jejunum',
#  'antenna',
#  'caudate-putamen',
#  'nictitating membrane',
#  'tumor/heart',
#  'fruit',
#  'pineal peduncle',
#  'sternum',
#  'plasma',
#  'gastrointestinal tract',
#  'carotid artery',
#  'hemolymph',
#  'larval stage',
#  'prosencephalon',
#  'rectum',
#  'epithelium',
#  'forelimb',
#  'cortex/striatum',
#  'liver/eyelid',
#  'neuromast',
#  'cerebral cortical neuron',
#  'quadriceps femoris',
#  'muscle tissue/plasma',
#  'cerebral ganglion',
#  'adipose tissue/plasma',
#  'breast/plasma',
#  'bulge',
#  'dorsal root ganglion',
#  'ileum',
#  'blood/muscle',
#  'intestinal epithelium',
#  'outer nuclear layer',
#  'renal cortex',
#  'sebum',
#  'smooth muscle tissue',
#  'umbilical artery',
#  'substantia nigra pars compacta',
#  'enteric nervous system',
#  'colon/plasma',
#  'lymph node',
#  'corpus striatum',
#  'stem',
#  '4 cell stage',
#  'hair',
#  'cerebrum',
#  'white muscle',
#  'resorption pit',
#  'fat pad',
#  'liver/plasma',
#  'umbilical cord blood',
#  'gingiva',
#  'gall bladder',
#  'medulla/pons',
#  'thoracic aorta',
#  'peripheral nerve',
#  'mesenteric lymph node',
#  'venous blood',
#  'brain/plasma',
#  'heart/kidney',
#  'knee',
#  'mesentery',
#  'tumor/large intestine',
#  'amygdala',
#  'dental follicle',
#  'hypothalamus',
#  'testis sheath',
#  'submucosa',
#  'gastric antrum',
#  'semitendinosus',
#  'placenta',
#  'epidermis',
#  'umbilical vein endothelium',
#  'prostate gland epithelium',
#  'mesenchyme',
#  'lens fiber',
#  'ventral striatum',
#  'basal forebrain',
#  'oviductal fluid',
#  'cortex/cerebellum',
#  'tooth germ',
#  'posterior segment of eyeball',
#  'surface structure',
#  'thorax muscle',
#  'peritoneal cavity',
#  'calvarium',
#  'parenchyma',
#  'inferior colliculus',
#  'brainstem',
#  'muscularis mucosa',
#  'distal tubule',
#  'epididymal fluid',
#  'myocardium',
#  'lateral ventricle',
#  'muscle of leg',
#  'lung/plasma',
#  'respiratory tract',
#  'foot pad',
#  'motor neuron',
#  'aortic smooth muscle',
#  'islets of langerhans',
#  'lateral septal nucleus',
#  'brainstem/cerebellum',
#  'tumor/small intestine',
#  'caecum',
#  'excreta',
#  'skin',
#  'lateral amygdaloid nucleus',
#  'nerve',
#  'mesenteric artery',
#  'vascular tissue',
#  'proximal convoluted tubule',
#  'root',
#  'vertebra',
#  'adductor muscle',
#  'labial gland',
#  'buttock',
#  'paraventricular nucleus',
#  'lumbar spinal cord',
#  'bile duct epithelium',
#  'autopod region',
#  'septum',
#  'stroma',
#  'ganglion',
#  'otic capsule',
#  'efferent nerve',
#  'cheek pouch',
#  'abdomen skin',
#  'gut/portal system',
#  'terminal bronchiole',
#  'saphenous artery',
#  'plasma/thymus',
#  'periodontal ligament',
#  'temporalis muscle/brain',
#  'optic lobe',
#  'tendon',
#  'uterine endometrium',
#  'lamina',
#  'respiratory system',
#  'hindlimb',
#  'atrium',
#  'left ventricle',
#  'blood vessel wall',
#  'uterine cervix',
#  'coronary artery',
#  'striated muscle',
#  'trachealis',
#  'pelvic ganglion',
#  'epithelial lining fluid',
#  'skeletal muscle/liver',
#  'mesopallium ventrale',
#  'reproductive organ',
#  'harderian gland/liver lobe',
#  'preputial gland',
#  'palpebral conjunctiva',
#  'muscle tissue',
#  'exodermis',
#  'oviduct',
#  'eyeball of camera-type eye',
#  'pineal gland',
#  'anal region',
#  'cheek',
#  'duodenal mucosa',
#  'adrenal medulla',
#  'urogenital tract',
#  'papilla',
#  'vena cava',
#  'stomach/plasma',
#  'olfactory cortex',
#  'blood/kidney',
#  'cerebral white matter',
#  'medial nidopallium',
#  'paraventricular nucleus of hypothalamus',
#  'placental labyrinth',
#  'cartilage',
#  'skin muscle',
#  'brain myelin',
#  'seminiferous tubule of testis',
#  'liver/blood',
#  'temporalis muscle/lung',
#  'vas deferens',
#  'notochord',
#  'lymph',
#  'shell',
#  'testis/plasma',
#  'paraventricular hypothalamic nucleus',
#  'foot muscle',
#  'brain',
#  'peritoneal fluid',
#  'pulmonary lobule',
#  'temporalis muscle/mesenteric fat',
#  'umbilical cord',
#  'vesicular gland',
#  'atrioventricular node',
#  'epithelial lining fluid/plasma',
#  'cns/plasma',
#  'ingested food',
#  'cerebrospinal fluid',
#  'saliva',
#  'synovial tissue',
#  'sublingual gland',
#  'pus',
#  'ommatidium',
#  'meningeal cluster',
#  'visual cortex',
#  'intervertebral disk',
#  'hepatic portal vein',
#  'instar larval stage',
#  'hypopharynx',
#  'perirenal fat',
#  'endocardium',
#  'epiphyseal plate',
#  'milk/plasma',
#  'cerebral hemisphere',
#  'vascular system',
#  'blood/plasma',
#  'blastula stage',
#  'abdominal fat pad',
#  'knee joint',
#  'xylem',
#  'submaxillary gland',
#  'sinoatrial node',
#  'putamen',
#  'striatum',
#  'endodermis',
#  'amniotic fluid',
#  'epiphyseal growth plate',
#  'splenic artery',
#  'portal triad',
#  'extension',
#  'viper venom',
#  'soleus',
#  'plasma/spleen',
#  'uterine lumen',
#  'auditory cortex',
#  'smooth muscle of trachea',
#  'larva',
#  'baroreceptor',
#  'condyle',
#  'muscle/brain',
#  'intraorbital lacrimal gland',
#  'lateral saphenous vein',
#  'paramedian lobule',
#  'temporalis muscle/heart',
#  'thalamus/cerebellum',
#  'liver/spleen',
#  'striatum/cerebellum',
#  'metaphysis',
#  'blood/thyroid',
#  'soleus muscle',
#  'pancreas/brain',
#  'central amygdaloid nucleus',
#  'decidua',
#  'glomerulus',
#  'airway epithelium',
#  'colon content',
#  'ankle/knee',
#  'heart/lung',
#  'trabecula',
#  'midgut secretion',
#  'chyme',
#  'skin of body',
#  'aortic valve',
#  'corpus epididymis',
#  'rhombomere 4',
#  'lateral line',
#  'csf/serum',
#  'chorionic villus',
#  'pulmonary artery endothelium',
#  'patella',
#  'liver',
#  'egg',
#  'tuber',
#  'serum/bone marrow',
#  'abdominal ganglion',
#  'blood/bone',
#  'buccal mucosa',
#  'amnion',
#  'central gray substance of midbrain',
#  'plasma/posterior eye cup',
#  'aorta',
#  'hippocampus',
#  'foreskin',
#  'hepatic vein',
#  'scalp',
#  'body wall muscle',
#  'breast muscle',
#  'upper respiratory tract',
#  'brown adipose tissue',
#  'seminal vesicle',
#  'tail skin',
#  'temporalis muscle/blood',
#  'tadpole',
#  'bile/liver',
#  'brain/serum',
#  'pleural effusion',
#  'diaphysis',
#  'luteal gland',
#  'cingulate cortex/cerebellum',
#  'liver/serum',
#  'bile/gall bladder',
#  'pupal stage',
#  'olfactory mucosa',
#  'endothelium',
#  'collecting duct',
#  'pit',
#  'dorsal horn of spinal cord',
#  'anterior hypodermis',
#  'vasculature',
#  'femoral vein',
#  'cardiac muscle',
#  'humerus',
#  'nymph stage',
#  'prostate/serum',
#  'mucus',
#  'motoneuron',
#  'meniscus',
#  'facial nucleus',
#  'electric organ',
#  'bone tissue',
#  'brown adipose tissue/blood',
#  'urine/feces',
#  'pore',
#  'ball',
#  'foot',
#  'nasopharynx',
#  'storage tissue',
#  'ciliary body',
#  'prostate gland ventral lobe',
#  'renal artery',
#  'forebrain',
#  'integument',
#  'leg',
#  'pulmonary surfactant',
#  'serum',
#  'habenula',
#  'right ear',
#  'pinna',
#  'sural nerve',
#  'sciatic nerve/plasma',
#  'yolk sac',
#  'aorta smooth muscle tissue',
#  'lung/blood',
#  'bronchoalveolar lavage/plasma',
#  'myelin sheath',
#  'colostrum',
#  'heart/femur',
#  'semen',
#  'frontal lobe',
#  'molaris',
#  'mammary epithelium',
#  'spinal cord segment',
#  'middle ear fluid/plasma',
#  'parotid gland',
#  'small intestine/plasma',
#  'albumen gland',
#  'cranium',
#  'pes',
#  'bulbar conjunctiva',
#  'insula',
#  'cervical ganglion',
#  'heart/muscle',
#  'gastric gland',
#  'thigh muscle',
#  'tumor/liver',
#  'tumor/tissue',
#  'corpus cavernosum',
#  'sputum',
#  'intestinal mucosa',
#  'blood clot',
#  'vascular endothelium',
#  'femoral artery',
#  'primary olfactory cortex',
#  'hindbrain',
#  'sebaceous gland',
#  'ependyma',
#  'lens',
#  'intestinal muscle',
#  'intestinal wall',
#  'thymus',
#  'synovial fluid',
#  'medulla of organ',
#  'lens of camera-type eye',
#  'plasma/prostate gland',
#  'barretts epithelium',
#  'smooth muscle',
#  'bone/muscle',
#  'nucleus accumbens',
#  'skeletal muscle',
#  'epitrochlearis muscle',
#  'thoracic ganglion',
#  'lateral geniculate body',
#  'right cardiac atrium',
#  'atherosclerotic plaque',
#  'internode',
#  'spleen',
#  'olfactory bulb',
#  'myotube',
#  'node',
#  'vermiform appendix',
#  'spiral organ of cochlea',
#  'gray matter',
#  'trunk',
#  'insula/cerebellum',
#  'peritoneum',
#  'lachrymal gland',
#  'tonsil',
#  'juvenile stage',
#  'bronchoalveolar lavage',
#  'yolk',
#  'epididymal fat/brain',
#  'anterior olfactory nucleus',
#  'adrenal gland',
#  'retinal pigment epithelium',
#  'corpus',
#  'phrenic nerve',
#  'colon',
#  'columella muscle',
#  'middle cerebral artery',
#  'cuneiform nucleus',
#  'ovarian surface epithelium',
#  'renal epithelium',
#  'filament',
#  'brain/liver',
#  'temporalis muscle/kidney',
#  'liver lobe',
#  'endoderm',
#  'olfactory tubercle',
#  'pancreatic juice',
#  'nucleus pulposus',
#  'superior cervical ganglion',
#  'animal cap',
#  'serum/tumor',
#  'nasal cartilage',
#  'hippocampus/plasma',
#  'corpus cardiacum',
#  'nervous system',
#  'tibial nerve',
#  'diaphragm',
#  'urinary tract',
#  'vagus nerve',
#  'thoracic cavity',
#  'connective tissue',
#  'raphe/cerebellum',
#  'female gonad',
#  'urinary bladder',
#  'interpeduncular nucleus',
#  'ventral tegmental area',
#  'seminal fluid',
#  'heart/plasma',
#  'phrenic nerve-diaphragm muscle',
#  'lower respiratory tract',
#  'parietal lobe',
#  'endometrium',
#  'trachea/thoracic aorta',
#  'olfactory tract',
#  'meningeal artery',
#  'sclera',
#  'skeletal system',
#  'preoptic area',
#  'layer of hippocampus',
#  'heart left ventricle',
#  'blood/ovary',
#  'caudate putamen',
#  'adipose',
#  'placental membrane',
#  'axillary lymph node',
#  'pad',
#  'male organism',
#  'bile/urine',
#  'larynx',
#  'sinusoidal space',
#  'neural crest',
#  'purkinje fiber',
#  'blood/femur',
#  'heart primordium',
#  'midbrain',
#  'nephron',
#  'cortex',
#  'tectum mesencephali',
#  'pulmonary artery',
#  'bone/plasma',
#  'sublingual',
#  'cardiac ventricle',
#  'medial amygdaloid nucleus',
#  'sympathetic nerve',
#  'renal medulla',
#  'caudal vein',
#  'shoulder',
#  'bile',
#  'talus',
#  'pleural cavity',
#  'myocardium/plasma',
#  'embryo',
#  'eye/plasma',
#  'venom',
#  'pancreas',
#  'heart',
#  'scale',
#  'tumor/spleen',
#  'csf/plasma',
#  'epididymal fat pad',
#  'lower lip',
#  'occipital cortex',
#  'extensor digitorum longus/blood',
#  'vertebral',
#  'peripheral blood',
#  'liver/lung',
#  'gut mucosa',
#  'thorax',
#  'early embryo',
#  'ventral pallidum',
#  'skin/blood',
#  'squamous epithelium',
#  'lymphoid tissue',
#  'left cardiac atrium',
#  'omentum',
#  'gastric mucosa',
#  'midbrain tectum',
#  'adventitia',
#  'sweat',
#  'cloaca',
#  'testis',
#  'fin',
#  'small intestine mucosa',
#  'marrow',
#  'mesoderm',
#  'cochlea',
#  'hip',
#  'harderian gland',
#  'ascitic fluid',
#  'cleavage stage',
#  'fiber',
#  'ovarian vein',
#  'cardiovascular system',
#  'neck',
#  'neocortex',
#  'pyramidalis',
#  'lamina propria',
#  'mucosa',
#  'parathyroid gland',
#  'extensor digitorum longus',
#  'crypt',
#  'portal vein',
#  'cuticle',
#  'retina',
#  'myelin',
#  'intersomitic vessel',
#  'midgut',
#  'portal system',
#  'brain ventricle',
#  'adrenal tissue',
#  'anterior cingulate cortex/cerebellum',
#  'olfactory epithelium',
#  'embryonic blood',
#  'gizzard',
#  'sensory neuron',
#  'syncytium',
#  'proximal tubule',
#  'csf/brain',
#  'oesophagus',
#  'right atrium/left atrium',
#  'soleus muscle/blood',
#  'olfactory lobe',
#  'long bone',
#  'excretory gland',
#  'quadriceps',
#  'cortex/pancreas',
#  'life cycle',
#  'cerebellar cortex',
#  'pituitary gland',
#  'pleural fluid',
#  'upper jaw region',
#  'gut',
#  'kidney/plasma',
#  'thyroid gland',
#  'hair/skin',
#  'exudate',
#  'brain frontal cortex/cerebellum',
#  'cardiac endothelium',
#  'glia',
#  'silk',
#  'bile duct',
#  'lacrimal',
#  'ligament',
#  'sphincter muscle',
#  'abdominal cavity',
#  'parabrachial nucleus',
#  'brown fat',
#  'seminiferous tubule',
#  'gonad',
#  'dermal papilla',
#  'cervical mucus',
#  'leg muscle',
#  'autonomic nervous system',
#  'temporal cortex',
#  'leaf',
#  'tail',
#  'ureter',
#  'dental pulp',
#  'mouth',
#  'medulla oblongata',
#  'entorhinal cortex',
#  'blood/pancreas',
#  'vulva',
#  'pulmonary epithelium',
#  'anococcygeus muscle',
#  'pyloric region',
#  'venule',
#  'mesenteric vein',
#  'skin/plasma',
#  'trachea',
#  'dermis',
#  'blood/semen',
#  'posterior midgut',
#  'mucosa of small intestine',
#  'csf/blood',
#  'thyroid',
#  'milk',
#  'thalamus',
#  'lobule',
#  'pancreas/temporal muscle',
#  'urothelium',
#  'uveal tract',
#  'piriform cortex',
#  'arterial blood',
#  'cocoon',
#  'trachea/plasma',
#  'inner ear',
#  'ileal mucosa',
#  'sciatic nerve',
#  'tumor/plasma',
#  'nasal cavity',
#  'medial geniculate body',
#  'papillary muscle',
#  'prostate gland',
#  'cingulate gyrus/cerebellum',
#  'craniofacial region',
#  'pupil',
#  'tracheal mucosa',
#  'kidney',
#  'tongue',
#  'epididymis',
#  'lung',
#  'ankle joint',
#  'artery',
#  'striatum/plasma',
#  'corneal epithelium',
#  'cortex/plasma',
#  'pons',
#  'endopiriform nucleus',
#  'colonic epithelium',
#  'aqueous humor of eyeball',
#  'intestine',
#  'gastrula',
#  'digestive juice',
#  'periosteum',
#  'artery/brain',
#  'atrioventricular bundle',
#  'submandibular gland',
#  'lymph gland',
#  'heart ventricle',
#  'lateral plate mesoderm',
#  'bronchus',
#  'pallidum',
#  'mammary gland',
#  'perforant path',
#  'face',
#  'vaginal fluid',
#  'calleja island',
#  'globus pallidus/cerebellum',
#  'albumen',
#  'egg yolk',
#  'uterine epithelium',
#  'anterior lateral plate mesoderm',
#  'deep vein',
#  'femur',
#  'urinary bladder/urine',
#  'adrenal cortex',
#  'pons/caudate',
#  'ovary epithelium',
#  'tumor/pancreas',
#  'skull',
#  'iliac artery',
#  'blood serum',
#  'arteriole',
#  'hyperpallium apicale',
#  'ear',
#  'nigrostriatal tract',
#  'vitreous humor',
#  'fat/muscle',
#  'colon/blood',
#  'cuspid',
#  'lung/muscle',
#  'vent',
#  'tumor/muscle',
#  'subiculum',
#  'spinal cord',
#  'thoracic nerve',
#  'thigh',
#  'tibialis',
#  'prostate',
#  'pectoral muscle',
#  'digestive gland',
#  'heart/liver',
#  'skeletal tissue',
#  'chest',
#  'metacestode',
#  'prostate epithelium',
#  'cerebellum',
#  'wing',
#  'levator ani muscle',
#  'saphenous vein',
#  'kidney/urine',
#  'definitive endoderm',
#  'lip',
#  'lower back',
#  'nose',
#  'airway smooth muscle',
#  'urine',
#  'proximal metaphysis',
#  'skin epidermis',
#  'horn',
#  'supraoptic nucleus',
#  'retina/plasma',
#  'brain/caudate',
#  'neck bone',
#  'tissue',
#  'distal metaphysis',
#  'hippocampus/cerebellum',
#  'adductor',
#  'blood/spleen',
#  'dentate gyrus',
#  'alimentary canal',
#  'left ear',
#  'celiac artery',
#  'uterus',
#  'area postrema',
#  'bronchiole',
#  'blood',
#  'salivary gland',
#  'granulation tissue',
#  'juice vesicle',
#  'neural tube',
#  'interstitial fluid',
#  'rhomboid',
#  'swim bladder',
#  'atherosclerotic carotid plaque',
#  'adrenal gland/plasma',
#  'vagina',
#  'ca1 stratum radiatum',
#  'spinal nerve',
#  'hepatobiliary system',
#  'head',
#  'spinal ganglion',
#  'ascites',
#  'tumor/kidney',
#  'limbic system',
#  'nucleus preopticus posterior',
#  'occipital lobe',
#  'ectoderm',
#  'helix',
#  'cardiac muscle of left ventricle',
#  'basilar artery',
#  'insular cortex',
#  'parietal cortex',
#  'female organism',
#  'small intestine',
#  'cerebral artery',
#  'lymph node/plasma',
#  'fetal membrane',
#  'body wall',
#  'tube',
#  'locus ceruleus',
#  'his-purkinje system',
#  'cardiac atrium',
#  'cerebellum/frontal lobe',
#  'microvessel',
#  'muscle',
#  'pancreas/liver',
#  'brain ventricle/choroid plexus',
#  'snake venom',
#  'uterine horns',
#  'cauda epididymis',
#  'tip',
#  'valve',
#  'immune system',
#  'neocortex/cerebellum',
#  'cingulate cortex',
#  'lobe',
#  'bone marrow',
#  'temporalis muscle/adrenal',
#  'limb',
#  'submaxillary gland/thyroid',
#  'arcuate nucleus',
#  'telencephalon',
#  'sigmoid colon',
#  'cecum',
#  'brain cortex',
#  'cervical epithelium',
#  'cell layer',
#  'central nervous system',
#  'umbilical vein',
#  'vein',
#  'esophageal sphincter',
#  'frontal cortex',
#  'pancreatic islet',
#  'leg nerve',
#  'white adipose tissue',
#  'blood/testes',
#  'tail vein',
#  'lung parenchyma',
#  'vessel',
#  'blood/uterus',
#  'tibialis anterior',
#  'bone element',
#  'striatopallidal complex/cerebellum',
#  'large intestine',
#  'tumor/lung',
#  'psoas muscle',
#  'gyrus',
#  'dorsal raphe nucleus/cerebellum',
#  'tubercle',
#  'morula',
#  'sinusoid',
#  'dorsum',
#  'chorioallantoic/vitelline membrane',
#  'neurofilament',
#  'chorion',
#  'circulatory system',
#  'fat body',
#  'gland',
#  'cerebral cortex',
#  'pectoral fin',
#  'synovial fluid/blood',
#  'brain stem',
#  'pupa']

# %% [markdown]
# ##### Then view overlap of terms in dictionary & those in cell finder

# %%
overlap = [term for term in tissue_check_set if term in tissue]
print("\n".join(overlap))
# Out:
# tissue
# immune system
# bone marrow
# blood
# peripheral blood
# liver

# %%
cellfinder_only = [term for term in tissue_check_set if term not in tissue]
print("\n".join(cellfinder_only))

# TODO - Coverage compared to cover of dictionary in sample
percent = len(cellfinder_only) / len(tissue) * 100
print('%.2f' % percent)
# Out:
# iver
# hematopoietic system
# cystic bodies
# myelomonocytic colonies
# human fetal liver
# clumps
# viral
# colonies
# fetal liver
# vector transduced colonies
# germ layers
# mobilized peripheral blood
# cells
# clusters
# anti-hiv
# embryonic cystic bodies
# monolayers
# fetal
# myeloid colonies
# feeder layers
# cord blood
# endothelial
# hiv-1
# layers
# myeloid lineages
# hematopoietic
# lentiviral
# lymphoid
# cystic body
# myelomonocytic
# vector
# blastocysts
# inner cell mass
# myeloid
# antiviral
# cell clumps
# embryonic
# stromal
# 3.80

# %%
dict_only = [term for term in tissue if term not in tissue_check_set]
# print("\n".join(dict_only))

# %%
tissue_check
# Out:
#        label  start    end              term
# 0    Anatomy   2664   2679   inner cell mass
# 11   Anatomy  30894  30910  Myeloid colonies
# 15   Anatomy   2689   2700       blastocysts
# 19   Anatomy   2284   2289             HIV-1
# 21   Anatomy   6371   6385    myelomonocytic
# ..       ...    ...    ...               ...
# 869  Anatomy  18280  18296  peripheral blood
# 877  Anatomy  18291  18296             blood
# 884  Anatomy  19552  19557             fetal
# 885  Anatomy  19558  19563             liver
# 887  Anatomy  23937  23950     hematopoietic
#
# [160 rows x 4 columns]

# %%
tissue_check_f = tissue_check[tissue_check["term"].isin(["iver"])]
s = tissue_check_f['start'].to_list()[0]
e = tissue_check_f['end'].to_list()[0]
