# %% [markdown]
# # Open source model and data reviews, for variants / AEs
#
# Related thoughts for use cases:
# - https://docs.google.com/document/d/1HDpOcQQOmT5A398j_qr-Hm3my4fjuZd8To1YTXhlXNg/edit?tab=t.0#heading=h.kt9y0vodzhfp
# - https://docs.google.com/document/d/1KGyr_zPBAdTophA-XGzkW0ObhVNMoKBhioJdpVpdnA0/edit?tab=t.0#heading=h.kfugo3aqnalh
#     - With this second example, we can see value in having models which can capture genevar, drug targets and adverse events

# %% [markdown]
# ### Beginning with protein structure NER model, sourced from https://huggingface.co/PDBEurope/BiomedNLP-PubMedBERT-ProteinStructure-NER-v3.1

# %%
from transformers import AutoTokenizer, AutoModelForTokenClassification

tokenizer = AutoTokenizer.from_pretrained("PDBEurope/BiomedNLP-PubMedBERT-ProteinStructure-NER-v3.1")
model = AutoModelForTokenClassification.from_pretrained("PDBEurope/BiomedNLP-PubMedBERT-ProteinStructure-NER-v3.1")
# Out:
# tokenizer_config.json:   0%|          | 0.00/394 [00:00<?, ?B/s]
# vocab.txt: 0.00B [00:00, ?B/s]
# special_tokens_map.json:   0%|          | 0.00/125 [00:00<?, ?B/s]
# config.json: 0.00B [00:00, ?B/s]
# model.safetensors:   0%|          | 0.00/436M [00:00<?, ?B/s]

# %%
import pandas as pd
import requests
from pprint import pprint
from typing import List, Tuple

# %%
def query_epmc(query: str, page_size: int = 10) -> List:
    query = f"{query} HAS_FT:Y AND OPEN_ACCESS:Y"
    url = "https://www.ebi.ac.uk/europepmc/webservices/rest/search"
    params = {
        "query": query,
        "format": "json",
        "pageSize": page_size
    }

    resp = requests.get(url, params=params)
    resp_json = resp.json()

    if 'resultList' in resp_json:
        # pprint(resp_json)
        pmcids = [i['pmcid'] for i in resp_json['resultList']['result']]
        return pmcids
    else:
        return []

# %%
papers = query_epmc(query="protein variant")
papers
# Out:
# ['PMC11843469',
#  'PMC10823009',
#  'PMC11301264',
#  'PMC10788875',
#  'PMC10232650',
#  'PMC9235876',
#  'PMC9293687',
#  'PMC9725131',
#  'PMC10016848',
#  'PMC8495913']

# %%
# Stuck with BioC given Melanie's model used the same / ease of use
def query_bioc(pmid: str) -> List:
    resp = requests.get(f"https://www.ncbi.nlm.nih.gov/research/bionlp/RESTful/pmcoa.cgi/BioC_json/{pmid}/unicode")
    resp_json = resp.json()
    # pprint(resp_json)
    text = []
    for search_hit in resp_json:
        docs = search_hit['documents']
        for doc in docs:
            passages = doc['passages']
            sections = []
            for block in passages:
                section = block['infons']['section_type']
                sections.append(section)
                text.append(block['text'])
                if section in ['INTRO', 'DISCUSS', 'RESULTS']:
                    text.append(block['text'])
            # print(list(set(sections)))
    return text

# %%
import torch

def run_model(
        input_text: List[str],
        batch_size: int=4,
        max_length: int=512) -> Tuple:

    all_results = []
    
    # Process in batches
    for i in range(0, len(input_text), batch_size):
        # Get the current batch
        batch_texts = input_text[i:i + batch_size]
        
        # Tokenize and pass to model
        inputs = tokenizer(batch_texts, return_tensors="pt", padding=True, truncation=True, max_length=max_length)

        with torch.no_grad():
            outputs = model(**inputs)

        # Decode predictions and configure id to label map
        predictions = torch.argmax(outputs.logits, dim=2)
        id_to_label = model.config.id2label

        # Review predictions
        for (original_text, input_ids, prediction_ids) in zip(batch_texts, inputs['input_ids'], predictions):
            
            # Decode tokens and predictions
            tokens = tokenizer.convert_ids_to_tokens(input_ids)
            labels = [id_to_label[pred_id.item()] for pred_id in prediction_ids]

            entities = []
            current_entity = None
            
            for token, label in zip(tokens, labels):
                if token in tokenizer.all_special_tokens:
                    continue

                if label.startswith("B-"):
                    if current_entity:
                        entities.append(current_entity)
                    
                    entity_type = label[2:]
                    current_entity = {"entity": token.replace("##", ""), "type": entity_type}
                
                elif label.startswith("I-"):
                    if current_entity:
                        if [x for x in [current_entity["entity"], token] if "-" in x]: 
                            token = " " + token.replace("##", "")
                            current_entity["entity"] += token
                        else:
                            token = " " + token.replace("##", "")
                            current_entity["entity"] += token
                    
                else:
                    if current_entity:
                        entities.append(current_entity)
                    current_entity = None
            
            if current_entity:
                entities.append(current_entity)

            all_results.append((original_text, entities))

    return all_results

# %%
'''
def run_model2(
        input_text: List[str],
        batch_size: int = 4,
        max_length: int = 512) -> Tuple:
    """
    Runs a named entity recognition (NER) model on a list of text inputs.
    This version correctly combines 'B-' and 'I-' parts of an entity.

    Args:
        input_text (List[str]): A list of strings to process.
        batch_size (int, optional): The number of texts to process in a single batch. Defaults to 4.
        max_length (int, optional): The maximum length for tokenization. Defaults to 512.

    Returns:
        Tuple: A tuple containing a list of tuples. Each inner tuple contains the
               original text and a list of identified entities.
    """
    all_results = []
    
    # Process in batches
    for i in range(0, len(input_text), batch_size):
        # Get the current batch
        batch_texts = input_text[i:i + batch_size]
        
        # Tokenize and pass to model
        inputs = tokenizer(batch_texts, return_tensors="pt", padding=True, truncation=True, max_length=max_length)
        inputs.to('cuda' if torch.cuda.is_available() else 'cpu') # Move tensors to GPU if available

        with torch.no_grad():
            outputs = model(**inputs)

        # Decode predictions and configure id to label map
        predictions = torch.argmax(outputs.logits, dim=2)
        id_to_label = model.config.id2label

        # Review predictions
        for (original_text, input_ids, prediction_ids) in zip(batch_texts, inputs['input_ids'], predictions):
            
            # Decode tokens and predictions
            tokens = tokenizer.convert_ids_to_tokens(input_ids)
            labels = [id_to_label[pred_id.item()] for pred_id in prediction_ids]

            entities = []
            current_entity = None
            
            for token, label in zip(tokens, labels):
                # Skip special tokens
                if token in tokenizer.all_special_tokens:
                    continue
                
                # Check for beginning of an entity
                if label.startswith("B-"):
                    # If there was a previous entity, append it
                    if current_entity:
                        entities.append(current_entity)
                    
                    entity_type = label[2:]
                    current_entity = {"entity": token.replace("##", ""), "type": entity_type}
                
                # Check for continuation of an entity
                elif label.startswith("I-"):
                    # If we are currently inside an entity, append the token
                    if current_entity and current_entity["type"] == label[2:]:
                        current_entity["entity"] += token.replace("##", "").replace(" ", "")
                    # If 'I-' label doesn't match the current entity type,
                    # treat it as a new entity (or a standalone 'I-' label, common error)
                    else:
                        if current_entity:
                            entities.append(current_entity)
                        
                        entity_type = label[2:]
                        current_entity = {"entity": token.replace("##", ""), "type": entity_type}

                # Check for 'O' / other labels
                else:
                    # If there was an entity, append it
                    if current_entity:
                        entities.append(current_entity)
                    current_entity = None
            
            # Append the last entity if the loop ends while one is present
            if current_entity:
                entities.append(current_entity)

            # Append the result for the current text
            all_results.append((original_text, entities))

    return all_results
    '''
# Out:
# '\ndef run_model2(\n        input_text: List[str],\n        batch_size: int = 4,\n        max_length: int = 512) -> Tuple:\n    """\n    Runs a named entity recognition (NER) model on a list of text inputs.\n    This version correctly combines \'B-\' and \'I-\' parts of an entity.\n\n    Args:\n        input_text (List[str]): A list of strings to process.\n        batch_size (int, optional): The number of texts to process in a single batch. Defaults to 4.\n        max_length (int, optional): The maximum length for tokenization. Defaults to 512.\n\n    Returns:\n        Tuple: A tuple containing a list of tuples. Each inner tuple contains the\n               original text and a list of identified entities.\n    """\n    all_results = []\n    \n    # Process in batches\n    for i in range(0, len(input_text), batch_size):\n        # Get the current batch\n        batch_texts = input_text[i:i + batch_size]\n        \n        # Tokenize and pass to model\n        inputs = tokenizer(batch_texts, return_tensors="pt", padding=True, truncation=True, max_length=max_length)\n        inputs.to(\'cuda\' if torch.cuda.is_available() else \'cpu\') # Move tensors to GPU if available\n\n        with torch.no_grad():\n            outputs = model(**inputs)\n\n        # Decode predictions and configure id to label map\n        predictions = torch.argmax(outputs.logits, dim=2)\n        id_to_label = model.config.id2label\n\n        # Review predictions\n        for (original_text, input_ids, prediction_ids) in zip(batch_texts, inputs[\'input_ids\'], predictions):\n            \n            # Decode tokens and predictions\n            tokens = tokenizer.convert_ids_to_tokens(input_ids)\n            labels = [id_to_label[pred_id.item()] for pred_id in prediction_ids]\n\n            entities = []\n            current_entity = None\n            \n            for token, label in zip(tokens, labels):\n                # Skip special tokens\n                if token in tokenizer.all_special_tokens:\n                    continue\n                \n                # Check for beginning of an entity\n                if label.startswith("B-"):\n                    # If there was a previous entity, append it\n                    if current_entity:\n                        entities.append(current_entity)\n                    \n                    entity_type = label[2:]\n                    current_entity = {"entity": token.replace("##", ""), "type": entity_type}\n                \n                # Check for continuation of an entity\n                elif label.startswith("I-"):\n                    # If we are currently inside an entity, append the token\n                    if current_entity and current_entity["type"] == label[2:]:\n                        current_entity["entity"] += token.replace("##", "").replace(" ", "")\n                    # If \'I-\' label doesn\'t match the current entity type,\n                    # treat it as a new entity (or a standalone \'I-\' label, common error)\n                    else:\n                        if current_entity:\n                            entities.append(current_entity)\n                        \n                        entity_type = label[2:]\n                        current_entity = {"entity": token.replace("##", ""), "type": entity_type}\n\n                # Check for \'O\' / other labels\n                else:\n                    # If there was an entity, append it\n                    if current_entity:\n                        entities.append(current_entity)\n                    current_entity = None\n            \n            # Append the last entity if the loop ends while one is present\n            if current_entity:\n                entities.append(current_entity)\n\n            # Append the result for the current text\n            all_results.append((original_text, entities))\n\n    return all_results\n    '

# %%
# test = run_model2(input_text)
# filter_res(test, "mutant")

# %%
input_text = query_bioc(pmid=papers[0])
# len(texts)
e = run_model(input_text=input_text)
# for (text, entity) in e:
#     if entity['type'] == "mutant":
#         print("Original text:")
#         pprint([x for x in original_text.split(sep='. ')])
#         print(f"Found term: {entity['entity']}\n - - - - - - - - -\n")
# Out:
# /Users/withers/GitProjects/OTAR3088/ner-model/lib/python3.10/site-packages/torch/nn/modules/module.py:1762: FutureWarning: `encoder_attention_mask` is deprecated and will be removed in version 4.55.0 for `BertSdpaSelfAttention.forward`.
#   return forward_call(*args, **kwargs)

# %%
def filter_res(results: List[Tuple], filter: str):
    for res in results:
        text = res[0]
        tagged = res[1]
        filtered = [x["entity"] for x in tagged if x["type"] == filter]
        if len(filtered) > 0:
            print("- - - - - - Original text - - - - -")
            pprint([x for x in text.split(sep='. ')])
            print(f"- - Terms tagged of type '{filter}' - -")
            pprint(filtered)

filter_res(e, "mutant")
# Out:
# - - - - - - Original text - - - - -
# ['Antibodies are critical tools in medicine and research, and their affinity '
#  'for their target antigens is a key determinant of their efficacy',
#  'Traditional antibody affinity maturation and interaction analyses are often '
#  'hampered by time‐consuming steps such as cloning, expression, purification, '
#  'and interaction assays',
#  'To address this, we have developed FASTIA (Fast Affinity Screening '
#  'Technology for Interaction Analysis), a novel platform that integrates rapid '
#  'gene fragment preparation, cell‐free protein synthesis, and bio‐layer '
#  'interferometry with non‐regenerative analysis',
#  'Using this approach, we can analyze the intermolecular interactions of over '
#  '20 variants over 2\u2009days, requiring only the parent protein expression '
#  'plasmid and basic equipment',
#  'We have demonstrated the ability of FASTIA to discriminate between '
#  'single‐domain antibody variants with different binding affinities using the '
#  'anti‐HEL VHH antibody D2‐L29, and mapped the results to the crystal '
#  'structure to identify key interaction sites',
#  'FASTIA provides results comparable to those obtained using traditional '
#  'methods',
#  'Our system bypasses the need for genetic engineering facilities and can be '
#  'easily adopted by laboratories, accelerating the protein engineering and '
#  'optimization processes',
#  'In addition, FASTIA is applicable to other protein–protein interactions, '
#  'making it a versatile tool for studying molecular recognition',
#  'FASTIA facilitates efficient affinity maturation, protein engineering, and '
#  'analysis of protein–protein interactions',
#  'This provides a rapid and accessible route for improving antibodies and a '
#  'broader understanding of protein interactions.']
# - - Terms tagged of type 'mutant' - -
# ['d2 ‐ l2 9']
# - - - - - - Original text - - - - -
# ['As a model system, we used the anti‐hen egg white lysozyme (HEL) VHH '
#  'antibody D2‐L29 (De Genst et al.,\xa0)',
#  'In order to investigate the interaction of the antibody with its antigen '
#  'HEL, we generated a comprehensive panel of 21 alanine mutants across all CDR '
#  'residues known to interact with the antigen according to structural studies',
#  'To prepare DNA templates for cell‐free expression using the PUREfrex system, '
#  'we constructed a plasmid containing the D2‐L29 gene downstream of the T7 '
#  'promoter, incorporating a C‐terminal 10xHis‐tag',
#  'This plasmid was then used as a template for PCR amplification of linear DNA '
#  'fragments incorporating the desired mutations',
#  'For each mutation, PCR primers were designed that introduced a specific '
#  'amino acid substitution and created an overlapping region for subsequent '
#  'assembly',
#  'Following PCR and DpnI digestion to remove the original plasmid template, '
#  'linear DNA fragments were assembled into circular plasmids using the '
#  'NEBuilder HiFi DNA Assembly',
#  'Finally, the region between the T7 promoter and the gene and the resulting '
#  'fragments were amplified by PCR and sequenced using Sanger sequencing to '
#  'confirm the presence of the desired mutation.']
# - - Terms tagged of type 'mutant' - -
# ['d2 ‐ l2 9', 'd2 ‐ l2 9']
# - - - - - - Original text - - - - -
# ['As a model system, we used the anti‐hen egg white lysozyme (HEL) VHH '
#  'antibody D2‐L29 (De Genst et al.,\xa0)',
#  'In order to investigate the interaction of the antibody with its antigen '
#  'HEL, we generated a comprehensive panel of 21 alanine mutants across all CDR '
#  'residues known to interact with the antigen according to structural studies',
#  'To prepare DNA templates for cell‐free expression using the PUREfrex system, '
#  'we constructed a plasmid containing the D2‐L29 gene downstream of the T7 '
#  'promoter, incorporating a C‐terminal 10xHis‐tag',
#  'This plasmid was then used as a template for PCR amplification of linear DNA '
#  'fragments incorporating the desired mutations',
#  'For each mutation, PCR primers were designed that introduced a specific '
#  'amino acid substitution and created an overlapping region for subsequent '
#  'assembly',
#  'Following PCR and DpnI digestion to remove the original plasmid template, '
#  'linear DNA fragments were assembled into circular plasmids using the '
#  'NEBuilder HiFi DNA Assembly',
#  'Finally, the region between the T7 promoter and the gene and the resulting '
#  'fragments were amplified by PCR and sequenced using Sanger sequencing to '
#  'confirm the presence of the desired mutation.']
# - - Terms tagged of type 'mutant' - -
# ['d2 ‐ l2 9', 'd2 ‐ l2 9']
# - - - - - - Original text - - - - -
# ['The prepared PCR fragments were used as templates for cell‐free protein '
#  'synthesis with the PUREfrex system',
#  'Each construct was synthesized in a 10\u2009μL reaction at 30°C for 3–4\u2009'
#  'h',
#  'The successful expression of D2‐L29 and its variants was confirmed using '
#  'western blotting (Figure\xa0S2).']
# - - Terms tagged of type 'mutant' - -
# ['d2 ‐ l2 9']
# - - - - - - Original text - - - - -
# ['The prepared PCR fragments were used as templates for cell‐free protein '
#  'synthesis with the PUREfrex system',
#  'Each construct was synthesized in a 10\u2009μL reaction at 30°C for 3–4\u2009'
#  'h',
#  'The successful expression of D2‐L29 and its variants was confirmed using '
#  'western blotting (Figure\xa0S2).']
# - - Terms tagged of type 'mutant' - -
# ['d2 ‐ l2 9']
# - - - - - - Original text - - - - -
# ['To prepare for BLI analysis, the reaction mixture was diluted in buffer and '
#  'loaded onto a BLI biosensor pre‐coated with an anti‐penta‐His antibody, thus '
#  'specifically capturing the expressed VHH',
#  'Subsequently, we assessed antibody–HEL interactions',
#  'In BLI, multiple sensors are typically used to simultaneously measure '
#  'interactions with different concentrations of an antigen',
#  'However, this approach necessitates preparing enough antibody to perform '
#  'measurements at each of these antigen concentrations',
#  'While measurements can also be performed using a single sensor over multiple '
#  'cycles, this process involves antibody capture and dissociation in each '
#  'cycle, making it excessively time‐consuming',
#  'To address this limitation, we adopted the non‐regenerative kinetics method, '
#  'also known as the single‐cycle kinetics method (Kamat & Rafique,\xa0), which '
#  'enables continuous analysis of antigen interactions across multiple '
#  'concentrations without the need for complete antigen dissociation',
#  'The sensorgrams are shown in Figure\xa02, and the kinetic parameters are '
#  'listed in Table\xa01',
#  'The wild type D2‐L29 antibody exhibited a K D value of 3.6\u2009nM',
#  'The alanine mutants exhibited a variety of binding behaviors, including '
#  'maintained, slightly reduced, and significantly reduced affinities.']
# - - Terms tagged of type 'mutant' - -
# ['d2 ‐ l2 9']
# - - - - - - Original text - - - - -
# ['To prepare for BLI analysis, the reaction mixture was diluted in buffer and '
#  'loaded onto a BLI biosensor pre‐coated with an anti‐penta‐His antibody, thus '
#  'specifically capturing the expressed VHH',
#  'Subsequently, we assessed antibody–HEL interactions',
#  'In BLI, multiple sensors are typically used to simultaneously measure '
#  'interactions with different concentrations of an antigen',
#  'However, this approach necessitates preparing enough antibody to perform '
#  'measurements at each of these antigen concentrations',
#  'While measurements can also be performed using a single sensor over multiple '
#  'cycles, this process involves antibody capture and dissociation in each '
#  'cycle, making it excessively time‐consuming',
#  'To address this limitation, we adopted the non‐regenerative kinetics method, '
#  'also known as the single‐cycle kinetics method (Kamat & Rafique,\xa0), which '
#  'enables continuous analysis of antigen interactions across multiple '
#  'concentrations without the need for complete antigen dissociation',
#  'The sensorgrams are shown in Figure\xa02, and the kinetic parameters are '
#  'listed in Table\xa01',
#  'The wild type D2‐L29 antibody exhibited a K D value of 3.6\u2009nM',
#  'The alanine mutants exhibited a variety of binding behaviors, including '
#  'maintained, slightly reduced, and significantly reduced affinities.']
# - - Terms tagged of type 'mutant' - -
# ['d2 ‐ l2 9']
# - - - - - - Original text - - - - -
# ['BLI sensorgrams of D2‐L29 variants',
#  'The gray dots represent the reference‐subtracted data, and the colored lines '
#  'represent the fitting curves',
#  'Red, 1\u2009nM HEL; green, 4\u2009nM HEL; orange, 16\u2009nM HEL; blue, '
#  '64\u2009nM HEL.']
# - - Terms tagged of type 'mutant' - -
# ['d2 ‐ l2 9']
# - - - - - - Original text - - - - -
# ['Kinetics parameters of D2‐L29 variants.']
# - - Terms tagged of type 'mutant' - -
# ['d2 ‐ l2 9']
# - - - - - - Original text - - - - -
# ['\tThis study (n\u2009=\u20093, average\u2009±\u2009SD)\tAkiba et al',
#  '\t \tkon\tkoff\tKD\tKD\t \t(×105\u2009M−1\u2009s−1)\t(×10−3\u2009s−1)\t(nM)\t'
#  '(nM)\t \tWT\t6.0\u2009±\u20090.7\t1.9\u2009±\u20090.5\t3.1\u2009±\u20090.4\t'
#  '7.6\u2009±\u20090.1\t \tV2A\t8.2\u2009±\u20090.3\t1.6\u2009±\u20090.2\t'
#  '2.2\u2009±\u20091.1\t—\t \tY29A\tN.D.\tN.D.\tN.D.\tN.D.\t \tK30A\t7.6\u2009'
#  '±\u20091.7\t2.4\u2009±\u20090.8\t3.1\u2009±\u20090.7\t—\t \tN31A\t6.7\u2009'
#  '±\u20092.5\t2.6\u2009±\u20090.3\t4.5\u2009±\u20092.4\t23\u2009±\u20091\t \t'
#  'F37A\t4.3\u2009±\u20091.7\t24\u2009±\u20094\t62\u2009±\u200924\t—\t \tD44A\t'
#  '6.2\u2009±\u20090.9\t2.4\u2009±\u20090.4\t4.0\u2009±\u20091.0\t—\t \tR45A\t'
#  '6.4\u2009±\u20092.5\t0.48\u2009±\u20090.07\t0.81\u2009±\u20090.27\t—\t \t'
#  'E46A\t7.4\u2009±\u20093.0\t1.4\u2009±\u20090.1\t2.1\u2009±\u20091.0\t—\t \t'
#  'G47A\t5.6\u2009±\u20091.6\t0.29\u2009±\u20090.06\t0.54\u2009±\u20090.15\t'
#  '—\t \tF50A\t5.5\u2009±\u20091.3\t8.9\u2009±\u20092.0\t17\u2009±\u20098\t'
#  '—\t \tY60A\t3.7\u2009±\u20090.8\t15\u2009±\u20091\t41\u2009±\u20091.3\t'
#  '533\u2009±\u200950a\t \tY100A\tN.D.\tN.D.\tN.D.\tN.D.\t \tR101Ab\t6.7\u2009'
#  '±\u20092.1\t4.8\u2009±\u20090.1\t7.5\u2009±\u20092.6\t—\t \tN102A\t5.4\u2009'
#  '±\u20090.8\t3.7\u2009±\u20090.3\t7.0\u2009±\u20091.4\t50\u2009±\u20090\t \t'
#  'Y103A\t6.0\u2009±\u20091.6\t2.4\u2009±\u20090.1\t4.3\u2009±\u20091.4\t—\t \t'
#  'Q105A\t6.1\u2009±\u20092.0\t4.7\u2009±\u20091.0\t8.8\u2009±\u20095.1\t'
#  '46\u2009±\u20090\t \tC106A\tN.D.\tN.D.\tN.D.\t—\t \tT108A\t4.6\u2009±\u2009'
#  '0.0\t5.3\u2009±\u20091.7\t11\u2009±\u20094\t31\u2009±\u20090\t \tR109A\t'
#  'N.D.\tN.D.\tN.D.\tN.D.\t \tY110A\t5.2\u2009±\u20091.0\t3.4\u2009±\u20090.5\t'
#  '6.8\u2009±\u20092.4\t—\t \tW111A\t4.3\u2009±\u20090.8\t11\u2009±\u20091\t'
#  '25\u2009±\u20096\t99\u2009±\u20091\t \t']
# - - Terms tagged of type 'mutant' - -
# ['v2',
#  'a',
#  'y2',
#  '9a',
#  'k3',
#  '0',
#  'a',
#  'n3',
#  '1a',
#  'f3',
#  '7a',
#  'd4',
#  '4a',
#  'r4',
#  '5a',
#  'e4',
#  '6a',
#  'g4',
#  '7a',
#  'f5',
#  '0',
#  'a',
#  'y',
#  '60',
#  'a',
#  'y1',
#  '00',
#  'a',
#  'r1',
#  '01',
#  'ab',
#  'n1',
#  '02',
#  'a',
#  'y1',
#  '03',
#  'a',
#  'q1',
#  '05',
#  'a',
#  'c10',
#  '6a',
#  't1',
#  '08',
#  'a',
#  'r1',
#  '09',
#  'a',
#  'y1',
#  '10a']
# - - - - - - Original text - - - - -
# ['Data measured in duplicate are shown for R101A.']
# - - Terms tagged of type 'mutant' - -
# ['r1', '01', 'a']
# - - - - - - Original text - - - - -
# ['To elucidate the effects of these mutations, the residues were colored '
#  'according to the change in affinity, and then mapped onto the crystal '
#  'structure of the D2‐L29‐HEL complex (Figure\xa03)',
#  'This revealed that specific regions (Y29, Y100, C106, and R109, shown in '
#  'red) exhibited a loss of interaction upon mutation, suggesting that they '
#  'were hotspots for the interaction',
#  'For C106A, the loss of intermolecular disulfide bridges is presumably '
#  'responsible for the conformational change in CDR3',
#  'Furthermore, the residues exhibiting reduced affinity due to mutations (F37, '
#  'F50, Y60, T108, and W111, shown in magenta), namely those crucial for '
#  'interactions, were concentrated in specific regions adjacent to the '
#  'identified hotspot regions',
#  'Conversely, some residues where the interaction was enhanced by the mutation '
#  '(R45 and G47, shown in blue) were identified, suggesting that optimization '
#  'of these regions could further enhance the interaction.']
# - - Terms tagged of type 'mutant' - -
# ['c10', '6a']
# - - - - - - Original text - - - - -
# ['To elucidate the effects of these mutations, the residues were colored '
#  'according to the change in affinity, and then mapped onto the crystal '
#  'structure of the D2‐L29‐HEL complex (Figure\xa03)',
#  'This revealed that specific regions (Y29, Y100, C106, and R109, shown in '
#  'red) exhibited a loss of interaction upon mutation, suggesting that they '
#  'were hotspots for the interaction',
#  'For C106A, the loss of intermolecular disulfide bridges is presumably '
#  'responsible for the conformational change in CDR3',
#  'Furthermore, the residues exhibiting reduced affinity due to mutations (F37, '
#  'F50, Y60, T108, and W111, shown in magenta), namely those crucial for '
#  'interactions, were concentrated in specific regions adjacent to the '
#  'identified hotspot regions',
#  'Conversely, some residues where the interaction was enhanced by the mutation '
#  '(R45 and G47, shown in blue) were identified, suggesting that optimization '
#  'of these regions could further enhance the interaction.']
# - - Terms tagged of type 'mutant' - -
# ['c10', '6a']
# - - - - - - Original text - - - - -
# ['Crystal structure of D2‐L29 in complex with HEL',
#  'The results of the alanine scanning experiment using FASTIA were mapped onto '
#  'the crystal structure',
#  '(a) The surface of HEL is shown in light blue and the structure of D2‐L29 is '
#  'shown as a ribbon',
#  'CDRs (Chothia definition) are highlighted in orange',
#  'Labeled residues indicated with side chains are the target residues for '
#  'which variants were created in this study',
#  '(b) Surface of D2‐L29 is shown',
#  'The coloring of the residues was based on the criteria described in the '
#  'following',
#  'Red, residues that lost interaction due to Ala mutation; magenta, residues '
#  'with more than 3‐fold decrease in affinity due to Ala mutation; green, '
#  'residues whose affinity was not severely altered by Ala mutation (1/3 to '
#  '3‐fold); blue, residues with more than 3‐fold increase in affinity due to '
#  'Ala mutation.']
# - - Terms tagged of type 'mutant' - -
# ['d2 ‐ l2 9', 'd2 ‐ l2 9', 'd2 ‐ l2 9']
# - - - - - - Original text - - - - -
# ['Analysis of the alanine scan data revealed that CDR3 plays a central role in '
#  'the interaction between D2‐L29 and HEL, consistent with its location in the '
#  'antibody–antigen interface',
#  'Several mutations within CDR3, including Y100A, C106A, T108A, and R109A, '
#  'resulted in a significant or complete loss of binding affinity (Table\xa01, '
#  'Figure\xa03)',
#  'Our results also demonstrate that framework regions (FRs) contribute to '
#  'antigen binding',
#  'In particular, F37A, F50A, Y60A, and W111A showed significant loss of '
#  'affinity',
#  'On the other hand, mutations in FR residues located at the periphery of the '
#  'interaction interface, such as R45A and G47A, led to a notable increase in '
#  'affinity (Table\xa01, Figure\xa03).']
# - - Terms tagged of type 'mutant' - -
# ['y1',
#  '00',
#  'a',
#  'c10',
#  '6a',
#  't1',
#  '08',
#  'a',
#  'r1',
#  '09',
#  'a',
#  'f3',
#  '7a',
#  'f5',
#  '0',
#  'a',
#  'y',
#  '60',
#  'a',
#  'w1',
#  '11a',
#  'r4',
#  '5a',
#  'g4',
#  '7a']
# - - - - - - Original text - - - - -
# ['Analysis of the alanine scan data revealed that CDR3 plays a central role in '
#  'the interaction between D2‐L29 and HEL, consistent with its location in the '
#  'antibody–antigen interface',
#  'Several mutations within CDR3, including Y100A, C106A, T108A, and R109A, '
#  'resulted in a significant or complete loss of binding affinity (Table\xa01, '
#  'Figure\xa03)',
#  'Our results also demonstrate that framework regions (FRs) contribute to '
#  'antigen binding',
#  'In particular, F37A, F50A, Y60A, and W111A showed significant loss of '
#  'affinity',
#  'On the other hand, mutations in FR residues located at the periphery of the '
#  'interaction interface, such as R45A and G47A, led to a notable increase in '
#  'affinity (Table\xa01, Figure\xa03).']
# - - Terms tagged of type 'mutant' - -
# ['y1',
#  '00',
#  'a',
#  'c10',
#  '6a',
#  't1',
#  '08',
#  'a',
#  'r1',
#  '09',
#  'a',
#  'f3',
#  '7a',
#  'f5',
#  '0',
#  'a',
#  'y',
#  '60',
#  'a',
#  'w1',
#  '11a',
#  'r4',
#  '5a',
#  'g4',
#  '7a']
# - - - - - - Original text - - - - -
# ['The gene encoding the anti‐HEL antibody VHH, D2‐L29, was cloned into a '
#  'pET28b‐based expression vector under the control of the T7 promoter '
#  'containing a C‐terminal 10xHis‐tag for purification and detection (Figure\xa0'
#  'S1)',
#  'The resulting plasmid served as a template for constructing the '
#  'antibody‐variant genes.']
# - - Terms tagged of type 'mutant' - -
# ['d2 ‐ l2 9']
# - - - - - - Original text - - - - -
# ['A panel of 21 alanine mutants targeting all CDR residues of the D2‐L29 VHH '
#  'was designed based on the crystal structure of the D2‐L29‐HEL complex (PDB '
#  'ID: 1ZV5), specifically targeting residues with a buried surface area (BSA) '
#  'greater than 0\u2009Å2 as determined by PDBePISA (Krissinel & Henrick,\xa0).']
# - - Terms tagged of type 'mutant' - -
# ['alanine mutants', 'd2 ‐ l2 9']

# %%
for p in papers:
    e = run_model(input_text=p)
# Out:
# /Users/withers/GitProjects/OTAR3088/ner-model/lib/python3.10/site-packages/torch/nn/modules/module.py:1762: FutureWarning: `encoder_attention_mask` is deprecated and will be removed in version 4.55.0 for `BertSdpaSelfAttention.forward`.
#   return forward_call(*args, **kwargs)

# %%
# Some gemini example sentences, these are more obvious examples of variants
protein_variant_sentences = [
    "Studies on the protein-protein interaction network revealed that the R175H variant of p53 dramatically alters its binding partners, shifting its function from a tumor suppressor to an oncogenic driver.",
    "The structural consequences of the E6V substitution in hemoglobin are profound, leading to the formation of rigid polymers that deform red blood cells into their characteristic sickle shape.",
    "The D90A mutation in superoxide dismutase 1 (SOD1) highlights the complexity of disease mechanisms, as its pathogenicity in familial ALS is not due to a loss of catalytic activity but rather to a gain of toxic function.",
    "The ΔF508 deletion in the CFTR protein prevents its proper folding, triggering the cell's quality control system to target the misfolded protein for destruction in the endoplasmic reticulum.",
    "Kinase inhibitors are now a standard therapy for melanoma patients with the V600E mutation in BRAF, which constitutively activates the downstream signaling cascade.",
    "The single amino acid change A67T in transthyretin increases its propensity to misfold and aggregate, forming amyloid fibrils that deposit in the heart and other tissues.",
    "The pathogenicity of the A223P variant in fibrillin-1 lies in its disruption of calcium-binding sites, which are critical for the formation of stable microfibrils in the extracellular matrix.",
    "Patients with familial chylomicronemia resulting from the S267L variant of lipoprotein lipase exhibit severely impaired lipid clearance due to the protein's reduced catalytic efficiency.",
    "The R117H amino acid substitution in Factor V makes it resistant to cleavage by activated protein C, a critical step in down-regulating blood coagulation.",
    "The P101S amino acid change in the prion protein (PrP) is a crucial determinant of disease pathology, as it favors the conversion of the normal PrP ($PrP^C$) into the disease-associated scrapie form ($PrP^{Sc}$).",
    "The E280A mutation in presenilin 1 alters the cleavage of the amyloid precursor protein (APP), leading to an overproduction of the highly aggregation-prone Aβ42 peptide.",
    "Achondroplasia is caused by a G380R variant in fibroblast growth factor receptor 3 (FGFR3), which leads to the constitutive activation of the receptor even in the absence of its ligand.",
    "The K456N variant of cardiac troponin I impairs the calcium-dependent regulation of myocardial contraction, which is the underlying cause of hypertrophic cardiomyopathy.",
    "The C278F substitution in fibroblast growth factor receptor 2 (FGFR2) is a well-known example of a gain-of-function mutation, leading to premature fusion of the cranial sutures.",
    "The C282Y variant in the HFE protein disrupts its interaction with the transferrin receptor, leading to a breakdown in the regulation of iron absorption.",
    "The p.L320P variant of lamin A/C causes dilated cardiomyopathy by compromising the structural integrity of the nuclear lamina and disrupting normal gene expression patterns.",
    "The S295C mutation in myotilin creates a new cysteine residue, which can form inappropriate disulfide bonds, leading to the formation of aggregates that interfere with muscle function.",
    "The R402Q variant in the ATP-binding cassette transporter A4 (ABCA4) disrupts its ability to transport retinoids, leading to the accumulation of toxic compounds in the retinal pigment epithelium.",
    "A study of familial ALS patients identified the H46R mutation in SOD1, which was shown to lead to a misfolding and aggregation of the protein that is toxic to motor neurons.",
    "The E258K mutation in lysosomal acid lipase is a clear example of a loss-of-function variant, as it severely impairs the protein's ability to hydrolyze cholesterol esters.",
    "Individuals homozygous for the M34T variant in connexin 26 (GJB2) often present with non-syndromic hearing loss due to the disruption of gap junction function in the inner ear.",
    "Congenital contractural arachnodactyly is associated with the K197R mutation in fibrillin-2, a protein crucial for elastic fiber formation in connective tissues.",
    "The L268P mutation in type II collagen (COL2A1) results in a protein with impaired triple helix formation, leading to the skeletal abnormalities characteristic of Stickler syndrome.",
    "The P1213L variant in dynein heavy chain 1 (DYNC1H1) compromises the protein's motor function, resulting in defects in retrograde axonal transport that cause spinal muscular atrophy.",
    "The R782W mutation in α₁-antitrypsin (SERPINA1) results in a misfolded protein that is trapped in the liver, leading to a lack of circulating α₁-antitrypsin in the lungs.",
    "The R136Q amino acid substitution in ubiquitin carboxyl-terminal hydrolase L1 (UCHL1) affects its deubiquitinating activity, which may contribute to the accumulation of protein aggregates observed in Parkinson's disease.",
    "The P270S variant in glucocerebrosidase (GBA1) has been shown to reduce the enzyme's activity, which is a known risk factor for Parkinson's disease.",
    "The A30P mutation in α-synuclein is a rare but well-documented cause of familial Parkinson's disease, as it promotes the formation of neurotoxic fibrils and Lewy bodies.",
    "The R46L variant in proprotein convertase subtilisin/kexin type 9 (PCSK9) is a functional polymorphism that reduces the protein's ability to degrade LDL receptors, leading to lower levels of circulating LDL cholesterol.",
    "The A152T variant in the protein tau (MAPT) is a known risk factor for frontotemporal dementia, as it enhances the aggregation and misfolding of the protein."
]

# %%
# Gemini mimicking descriptions of paper results, for protein variants then non-coding genetic variants to see what happens
protein_variant_sentences_experimental_results = [
    "Circular dichroism spectroscopy of the R175H p53 variant revealed a significant decrease in α-helical content compared to the wild-type protein, indicating a loss of structural integrity.",
    "In our gel electrophoresis assays, the E6V hemoglobin variant showed a distinct band shift in non-denaturing conditions, consistent with polymer formation under deoxygenated states.",
    "Immunoblot analysis of cells expressing the D90A SOD1 variant demonstrated a marked increase in detergent-insoluble protein, suggesting a propensity for aggregation.",
    "Western blot analysis of the ΔF508 CFTR variant showed a complete absence of the mature, fully glycosylated band, confirming that the protein is not trafficked to the cell surface.",
    "In vitro kinase assays confirmed a 500-fold increase in the phosphorylation of ERK and MEK substrates when using the V600E BRAF variant, demonstrating constitutive activation.",
    "Fluorescence microscopy with Thioflavin S staining revealed abundant amyloid deposits in cardiac tissue sections from mice expressing the A67T transthyretin variant.",
    "Our surface plasmon resonance (SPR) data demonstrated that the A223P fibrillin-1 variant has a significantly reduced binding affinity for calcium ions (Kd = 450 nM vs 50 nM for WT).",
    "Lipolysis assays using the S267L lipoprotein lipase variant showed only 15% of the catalytic activity observed with the wild-type enzyme.",
    "Coagulation assays of plasma containing the R117H Factor V variant showed a 12-fold increase in clotting time after the addition of activated protein C, confirming its resistance to inactivation.",
    "Real-time quaking-induced conversion (RT-QuIC) assays demonstrated that the P101S prion protein variant seeded the rapid formation of fibrils at a concentration 100-fold lower than the wild-type protein.",
    "Cell-free cleavage assays confirmed that the E280A presenilin 1 variant preferentially generated the highly amyloidogenic Aβ42 peptide over the Aβ40 peptide.",
    "Dual-luciferase reporter assays confirmed a 20-fold increase in STAT3 signaling in cells expressing the G380R FGFR3 variant, even in the absence of exogenous FGF ligand.",
    "Calcium-sensitizing assays on skinned cardiac muscle fibers revealed that the K456N troponin I variant increased the calcium sensitivity of force generation by 2.5-fold.",
    "Immunofluorescence staining revealed that the C278F FGFR2 variant localized to the cell membrane at a higher density and for a longer duration than the wild-type protein.",
    "In our iron uptake experiments, cells expressing the C282Y HFE variant failed to show the characteristic down-regulation of transferrin receptor expression in response to high iron levels.",
    "Immunoblotting of nuclear fractions showed a fragmented lamin A/C network in cells from patients with the p.L320P variant, indicating a loss of nuclear integrity.",
    "Pull-down assays with a cysteine-reactive probe demonstrated that the S295C myotilin mutation forms intermolecular disulfide bonds, leading to the formation of high-molecular-weight aggregates.",
    "Liposome-based transport assays using the R402Q ABCA4 variant showed a 90% reduction in the translocation of all-trans-retinal across the membrane.",
    "Immunohistochemistry of spinal cord sections from transgenic mice expressing the H46R SOD1 variant revealed extensive intracellular inclusions in motor neurons, which were immunoreactive for ubiquitin.",
    "In vitro enzyme kinetics demonstrated that the E258K lysosomal acid lipase variant had a Vmax that was less than 5% of the wild-type enzyme, confirming a severe loss-of-function.",
    "Dye-transfer assays showed a complete failure of Lucifer yellow transfer between cells expressing the M34T connexin 26 variant, indicating a loss of gap junction function.",
    "Atomic force microscopy of extracellular matrix fibers from cells expressing the K197R fibrillin-2 variant revealed an aberrant, disorganized microfibril network.",
    "A triple helix formation assay using purified L268P collagen type II demonstrated a significant reduction in the protein's ability to form stable triple helices.",
    "Live-cell imaging of retrograde axonal transport in neurons with the P1213L dynein heavy chain 1 variant showed a 75% decrease in the speed of cargo movement toward the cell body.",
    "Immunofluorescence of liver tissue from a patient with the R782W α₁-antitrypsin variant revealed abundant inclusions of the protein within hepatocytes, confirming its failure to be secreted.",
    "The R136Q UCHL1 variant showed a 5-fold decrease in its isopeptidase activity against a ubiquitinated substrate in a mass spectrometry-based enzymatic assay.",
    "In a fluorometric enzyme assay, the P270S glucocerebrosidase variant exhibited only 40% of the catalytic activity observed with the wild-type protein.",
    "Transmission electron microscopy of neuronal cultures expressing the A30P α-synuclein variant showed the presence of abundant fibrillar aggregates, similar to those found in Lewy bodies.",
    "In our binding assays, the R46L PCSK9 variant demonstrated a 3-fold decrease in its binding affinity for the LDL receptor, leading to a reduced rate of receptor degradation.",
    "Confocal microscopy of cells expressing the A152T tau variant revealed a significant increase in the formation of puncta and filamentous structures, suggesting enhanced aggregation."
]

non_coding_variant_sentences = [
    "Using a dual-luciferase reporter assay, we demonstrated that the SNP rs6983267, located in a long-range enhancer for the MYC oncogene, significantly increased reporter gene expression by 2.5-fold in colon cancer cell lines.",
    "Chromatin immunoprecipitation followed by sequencing (ChIP-seq) for the transcription factor TCF7L2 revealed a loss of binding at the promoter of the TCF7L2 gene in the presence of the rs7903146 risk allele.",
    "Our massively parallel reporter assay (MPRA) data showed that the A>T variant in the 3' UTR of the NOS1AP gene reduced the expression of a linked fluorescent reporter by 40% in cardiomyocyte cells.",
    "Sanger sequencing of the TERT promoter in melanoma samples identified two recurrent non-coding variants, c.-124C>T and c.-146C>T, which were shown by RT-qPCR to increase TERT mRNA expression by 15- and 20-fold, respectively.",
    "A quantitative chromatin conformation capture (3C) assay demonstrated that the rs9349379 SNP in a genomic insulator element disrupts the physical loop connecting the ESR1 promoter to its upstream enhancer.",
    "Minigene splicing assays confirmed that the deep intronic variant IVS21-12C>T in the CFTR gene leads to the creation of a cryptic splice site, resulting in a mis-spliced transcript lacking exon 22.",
    "In a yeast-based screen, we found that a 15-bp deletion within the HBB promoter region completely abolished the binding of the GATA-1 transcription factor, consistent with the observed phenotype in beta-thalassemia patients.",
    "We performed allelic expression analysis on post-mortem brain tissue and found that the rs12913832 SNP in the OCA2 gene enhancer was strongly associated with a 50% decrease in its expression.",
    "Our electro mobility shift assay (EMSA) results showed that the C>G SNP in the MDM2 promoter creates a novel high-affinity binding site for the SP1 transcription factor, leading to increased MDM2 transcription.",
    "RNA-seq analysis of patient-derived lymphoblastoid cell lines with the rs2201397 SNP in the TRIM59 3' UTR showed a significant upregulation of TRIM59 transcript levels, which we hypothesize is due to altered microRNA binding.",
    "Using CRISPR-Cas9 to introduce the rs7552554 variant in the promoter region of the MYB oncogene, we observed a 3-fold increase in H3K27ac histone marks, indicating enhanced enhancer activity.",
    "The 5-kb deletion upstream of the SOX2 gene was found to completely abrogate the expression of the gene in embryonic stem cells, suggesting the removal of a critical long-range enhancer.",
    "In a high-throughput screen, we identified an A>G variant in the promoter of a lncRNA that significantly decreased its transcription by 75% in a disease-relevant cell model.",
    "Our Northern blot analysis revealed that the rs10825036 SNP in the 3' UTR of the MIR-499 gene resulted in a mature miRNA transcript that was 50% less abundant compared to the wild-type allele.",
    "Allele-specific chromatin accessibility assays (ATAC-seq) revealed a loss of an open chromatin region at the locus containing the rs12740374 variant, suggesting a disruption of a transcription factor binding site.",
    "The 3' UTR of the KRAS gene containing the rs61764370 variant was cloned into a reporter plasmid, and subsequent luciferase assays showed a significant reduction in luciferase activity, consistent with altered miRNA-mediated repression.",
    "Chr-RNA FISH experiments confirmed that the C>T mutation in the SHH limb enhancer region failed to form a chromatin loop with the SHH promoter, explaining the observed limb malformations.",
    "Reporter gene assays showed that the rs11603334 SNP in the ARAP1 promoter led to a 2-fold upregulation of gene expression in pancreatic beta cells, which was corroborated by decreased binding of PAX4 and PAX6 transcription factors in EMSA.",
    "We used CRISPR-based tiling scans to systematically test variants in the LDLR promoter, finding that a specific A>C substitution reduced promoter activity by 60%, a key finding for familial hypercholesterolemia.",
    "RNA-seq of patient tumor samples with the rs73183594 variant in the IRF4 enhancer showed a significant increase in IRF4 mRNA expression levels, suggesting a gain-of-function mechanism.",
    "Our allele-specific sequencing analysis of RNA from heterozygous individuals demonstrated that the rs3796548 SNP, a non-coding variant, leads to a 3-fold increase in the expression of the TULP3 gene.",
    "The deletion of an enhancer 150 kb upstream of the GATA6 gene was found to cause a loss of GATA6 protein expression in pancreatic progenitor cells, as confirmed by immunostaining.",
    "Using a high-resolution 4C-seq, we mapped the chromosomal interactions of the genomic region containing a non-coding variant, revealing the creation of a novel chromatin loop between a distant enhancer and an oncogene.",
    "A minigene assay showed that a single nucleotide variant (G>A) in the 5' untranslated region of an unknown gene caused an increase in ribosome readthrough and protein translation.",
    "Quantitative real-time PCR (qRT-PCR) from patient fibroblasts with a deep intronic variant in the IDUA gene revealed a reduced level of the fully spliced transcript and an increase in a mis-spliced isoform.",
    "The C>G variant in the promoter of the CASP8 gene, located in a CpG island, was shown by methylation-specific PCR to be associated with a complete loss of DNA methylation and subsequent gene silencing.",
    "In our chromatin accessibility assay, the A>G SNP in the FTO enhancer was found to disrupt the binding of the ARID5B transcription factor, leading to a downstream effect on gene regulation.",
    "Our reporter assay demonstrated that the rs1403565 variant in the PITX2 enhancer increased the transcriptional activity of a reporter construct by 30% in cardiac tissue cells.",
    "The insertion of a SINE retrotransposon into the promoter of the FGFR2 gene was shown by reporter assays to completely abolish the gene's promoter activity in fibroblasts.",
    "CRISPR activation experiments using a sgRNA targeting the promoter region of a lncRNA confirmed that a non-coding variant within this region was responsible for a significant reduction in gene expression."
]

# %%
gemini_egs = run_model(input_text=protein_variant_sentences)
filter_res(gemini_egs, "mutant")
# Out:
# - - - - - - Original text - - - - -
# ['Studies on the protein-protein interaction network revealed that the R175H '
#  'variant of p53 dramatically alters its binding partners, shifting its '
#  'function from a tumor suppressor to an oncogenic driver.']
# - - Terms tagged of type 'mutant' - -
# ['r1', '75', 'h']
# - - - - - - Original text - - - - -
# ['The structural consequences of the E6V substitution in hemoglobin are '
#  'profound, leading to the formation of rigid polymers that deform red blood '
#  'cells into their characteristic sickle shape.']
# - - Terms tagged of type 'mutant' - -
# ['e6', 'v']
# - - - - - - Original text - - - - -
# ['The D90A mutation in superoxide dismutase 1 (SOD1) highlights the complexity '
#  'of disease mechanisms, as its pathogenicity in familial ALS is not due to a '
#  'loss of catalytic activity but rather to a gain of toxic function.']
# - - Terms tagged of type 'mutant' - -
# ['d', '90', 'a']
# - - - - - - Original text - - - - -
# ['The ΔF508 deletion in the CFTR protein prevents its proper folding, '
#  "triggering the cell's quality control system to target the misfolded protein "
#  'for destruction in the endoplasmic reticulum.']
# - - Terms tagged of type 'mutant' - -
# ['δf', '508']
# - - - - - - Original text - - - - -
# ['Kinase inhibitors are now a standard therapy for melanoma patients with the '
#  'V600E mutation in BRAF, which constitutively activates the downstream '
#  'signaling cascade.']
# - - Terms tagged of type 'mutant' - -
# ['v600e']
# - - - - - - Original text - - - - -
# ['The single amino acid change A67T in transthyretin increases its propensity '
#  'to misfold and aggregate, forming amyloid fibrils that deposit in the heart '
#  'and other tissues.']
# - - Terms tagged of type 'mutant' - -
# ['a6', '7', 't']
# - - - - - - Original text - - - - -
# ['The pathogenicity of the A223P variant in fibrillin-1 lies in its disruption '
#  'of calcium-binding sites, which are critical for the formation of stable '
#  'microfibrils in the extracellular matrix.']
# - - Terms tagged of type 'mutant' - -
# ['a2', '23', 'p']
# - - - - - - Original text - - - - -
# ['Patients with familial chylomicronemia resulting from the S267L variant of '
#  'lipoprotein lipase exhibit severely impaired lipid clearance due to the '
#  "protein's reduced catalytic efficiency."]
# - - Terms tagged of type 'mutant' - -
# ['s2', '67', 'l']
# - - - - - - Original text - - - - -
# ['The R117H amino acid substitution in Factor V makes it resistant to cleavage '
#  'by activated protein C, a critical step in down-regulating blood '
#  'coagulation.']
# - - Terms tagged of type 'mutant' - -
# ['r1', '17', 'h']
# - - - - - - Original text - - - - -
# ['The P101S amino acid change in the prion protein (PrP) is a crucial '
#  'determinant of disease pathology, as it favors the conversion of the normal '
#  'PrP ($PrP^C$) into the disease-associated scrapie form ($PrP^{Sc}$).']
# - - Terms tagged of type 'mutant' - -
# ['p10', '1s']
# - - - - - - Original text - - - - -
# ['The E280A mutation in presenilin 1 alters the cleavage of the amyloid '
#  'precursor protein (APP), leading to an overproduction of the highly '
#  'aggregation-prone Aβ42 peptide.']
# - - Terms tagged of type 'mutant' - -
# ['e2', '80', 'a']
# - - - - - - Original text - - - - -
# ['Achondroplasia is caused by a G380R variant in fibroblast growth factor '
#  'receptor 3 (FGFR3), which leads to the constitutive activation of the '
#  'receptor even in the absence of its ligand.']
# - - Terms tagged of type 'mutant' - -
# ['g3', '80', 'r']
# - - - - - - Original text - - - - -
# ['The K456N variant of cardiac troponin I impairs the calcium-dependent '
#  'regulation of myocardial contraction, which is the underlying cause of '
#  'hypertrophic cardiomyopathy.']
# - - Terms tagged of type 'mutant' - -
# ['k4', '56', 'n']
# - - - - - - Original text - - - - -
# ['The C278F substitution in fibroblast growth factor receptor 2 (FGFR2) is a '
#  'well-known example of a gain-of-function mutation, leading to premature '
#  'fusion of the cranial sutures.']
# - - Terms tagged of type 'mutant' - -
# ['c2', '78', 'f']
# - - - - - - Original text - - - - -
# ['The C282Y variant in the HFE protein disrupts its interaction with the '
#  'transferrin receptor, leading to a breakdown in the regulation of iron '
#  'absorption.']
# - - Terms tagged of type 'mutant' - -
# ['c2', '82', 'y']
# - - - - - - Original text - - - - -
# ['The p.L320P variant of lamin A/C causes dilated cardiomyopathy by '
#  'compromising the structural integrity of the nuclear lamina and disrupting '
#  'normal gene expression patterns.']
# - - Terms tagged of type 'mutant' - -
# ['p .', 'l3', '20', 'p']
# - - - - - - Original text - - - - -
# ['The S295C mutation in myotilin creates a new cysteine residue, which can '
#  'form inappropriate disulfide bonds, leading to the formation of aggregates '
#  'that interfere with muscle function.']
# - - Terms tagged of type 'mutant' - -
# ['s2', '95', 'c']
# - - - - - - Original text - - - - -
# ['The R402Q variant in the ATP-binding cassette transporter A4 (ABCA4) '
#  'disrupts its ability to transport retinoids, leading to the accumulation of '
#  'toxic compounds in the retinal pigment epithelium.']
# - - Terms tagged of type 'mutant' - -
# ['r4', '02', 'q']
# - - - - - - Original text - - - - -
# ['A study of familial ALS patients identified the H46R mutation in SOD1, which '
#  'was shown to lead to a misfolding and aggregation of the protein that is '
#  'toxic to motor neurons.']
# - - Terms tagged of type 'mutant' - -
# ['h4', '6', 'r']
# - - - - - - Original text - - - - -
# ['The E258K mutation in lysosomal acid lipase is a clear example of a '
#  "loss-of-function variant, as it severely impairs the protein's ability to "
#  'hydrolyze cholesterol esters.']
# - - Terms tagged of type 'mutant' - -
# ['e2', '58', 'k']
# - - - - - - Original text - - - - -
# ['Individuals homozygous for the M34T variant in connexin 26 (GJB2) often '
#  'present with non-syndromic hearing loss due to the disruption of gap '
#  'junction function in the inner ear.']
# - - Terms tagged of type 'mutant' - -
# ['m3', '4', 't']
# - - - - - - Original text - - - - -
# ['Congenital contractural arachnodactyly is associated with the K197R mutation '
#  'in fibrillin-2, a protein crucial for elastic fiber formation in connective '
#  'tissues.']
# - - Terms tagged of type 'mutant' - -
# ['k1', '97', 'r']
# - - - - - - Original text - - - - -
# ['The L268P mutation in type II collagen (COL2A1) results in a protein with '
#  'impaired triple helix formation, leading to the skeletal abnormalities '
#  'characteristic of Stickler syndrome.']
# - - Terms tagged of type 'mutant' - -
# ['l2', '68', 'p']
# - - - - - - Original text - - - - -
# ['The P1213L variant in dynein heavy chain 1 (DYNC1H1) compromises the '
#  "protein's motor function, resulting in defects in retrograde axonal "
#  'transport that cause spinal muscular atrophy.']
# - - Terms tagged of type 'mutant' - -
# ['p12', '13', 'l']
# - - - - - - Original text - - - - -
# ['The R782W mutation in α₁-antitrypsin (SERPINA1) results in a misfolded '
#  'protein that is trapped in the liver, leading to a lack of circulating '
#  'α₁-antitrypsin in the lungs.']
# - - Terms tagged of type 'mutant' - -
# ['r7', '82', 'w']
# - - - - - - Original text - - - - -
# ['The R136Q amino acid substitution in ubiquitin carboxyl-terminal hydrolase '
#  'L1 (UCHL1) affects its deubiquitinating activity, which may contribute to '
#  "the accumulation of protein aggregates observed in Parkinson's disease."]
# - - Terms tagged of type 'mutant' - -
# ['r1', '36', 'q']
# - - - - - - Original text - - - - -
# ['The P270S variant in glucocerebrosidase (GBA1) has been shown to reduce the '
#  "enzyme's activity, which is a known risk factor for Parkinson's disease."]
# - - Terms tagged of type 'mutant' - -
# ['p27', '0', 's']
# - - - - - - Original text - - - - -
# ['The A30P mutation in α-synuclein is a rare but well-documented cause of '
#  "familial Parkinson's disease, as it promotes the formation of neurotoxic "
#  'fibrils and Lewy bodies.']
# - - Terms tagged of type 'mutant' - -
# ['a3', '0', 'p']
# - - - - - - Original text - - - - -
# ['The R46L variant in proprotein convertase subtilisin/kexin type 9 (PCSK9) is '
#  "a functional polymorphism that reduces the protein's ability to degrade LDL "
#  'receptors, leading to lower levels of circulating LDL cholesterol.']
# - - Terms tagged of type 'mutant' - -
# ['r4', '6', 'l']
# - - - - - - Original text - - - - -
# ['The A152T variant in the protein tau (MAPT) is a known risk factor for '
#  'frontotemporal dementia, as it enhances the aggregation and misfolding of '
#  'the protein.']
# - - Terms tagged of type 'mutant' - -
# ['a1', '52', 't']

# %%
gemini_exps = run_model(input_text=protein_variant_sentences_experimental_results)
filter_res(gemini_exps, "mutant")
# Out:
# - - - - - - Original text - - - - -
# ['Circular dichroism spectroscopy of the R175H p53 variant revealed a '
#  'significant decrease in α-helical content compared to the wild-type protein, '
#  'indicating a loss of structural integrity.']
# - - Terms tagged of type 'mutant' - -
# ['r1', '75', 'h']
# - - - - - - Original text - - - - -
# ['In our gel electrophoresis assays, the E6V hemoglobin variant showed a '
#  'distinct band shift in non-denaturing conditions, consistent with polymer '
#  'formation under deoxygenated states.']
# - - Terms tagged of type 'mutant' - -
# ['e6', 'v']
# - - - - - - Original text - - - - -
# ['Immunoblot analysis of cells expressing the D90A SOD1 variant demonstrated a '
#  'marked increase in detergent-insoluble protein, suggesting a propensity for '
#  'aggregation.']
# - - Terms tagged of type 'mutant' - -
# ['d', '90', 'a']
# - - - - - - Original text - - - - -
# ['Western blot analysis of the ΔF508 CFTR variant showed a complete absence of '
#  'the mature, fully glycosylated band, confirming that the protein is not '
#  'trafficked to the cell surface.']
# - - Terms tagged of type 'mutant' - -
# ['δf', '508']
# - - - - - - Original text - - - - -
# ['In vitro kinase assays confirmed a 500-fold increase in the phosphorylation '
#  'of ERK and MEK substrates when using the V600E BRAF variant, demonstrating '
#  'constitutive activation.']
# - - Terms tagged of type 'mutant' - -
# ['v600e']
# - - - - - - Original text - - - - -
# ['Fluorescence microscopy with Thioflavin S staining revealed abundant amyloid '
#  'deposits in cardiac tissue sections from mice expressing the A67T '
#  'transthyretin variant.']
# - - Terms tagged of type 'mutant' - -
# ['a6', '7', 't']
# - - - - - - Original text - - - - -
# ['Our surface plasmon resonance (SPR) data demonstrated that the A223P '
#  'fibrillin-1 variant has a significantly reduced binding affinity for calcium '
#  'ions (Kd = 450 nM vs 50 nM for WT).']
# - - Terms tagged of type 'mutant' - -
# ['a2', '23', 'p']
# - - - - - - Original text - - - - -
# ['Lipolysis assays using the S267L lipoprotein lipase variant showed only 15% '
#  'of the catalytic activity observed with the wild-type enzyme.']
# - - Terms tagged of type 'mutant' - -
# ['s2', '67', 'l']
# - - - - - - Original text - - - - -
# ['Coagulation assays of plasma containing the R117H Factor V variant showed a '
#  '12-fold increase in clotting time after the addition of activated protein C, '
#  'confirming its resistance to inactivation.']
# - - Terms tagged of type 'mutant' - -
# ['r1', '17', 'h']
# - - - - - - Original text - - - - -
# ['Real-time quaking-induced conversion (RT-QuIC) assays demonstrated that the '
#  'P101S prion protein variant seeded the rapid formation of fibrils at a '
#  'concentration 100-fold lower than the wild-type protein.']
# - - Terms tagged of type 'mutant' - -
# ['p10', '1s']
# - - - - - - Original text - - - - -
# ['Cell-free cleavage assays confirmed that the E280A presenilin 1 variant '
#  'preferentially generated the highly amyloidogenic Aβ42 peptide over the Aβ40 '
#  'peptide.']
# - - Terms tagged of type 'mutant' - -
# ['e2', '80', 'a']
# - - - - - - Original text - - - - -
# ['Dual-luciferase reporter assays confirmed a 20-fold increase in STAT3 '
#  'signaling in cells expressing the G380R FGFR3 variant, even in the absence '
#  'of exogenous FGF ligand.']
# - - Terms tagged of type 'mutant' - -
# ['g3', '80', 'r']
# - - - - - - Original text - - - - -
# ['Calcium-sensitizing assays on skinned cardiac muscle fibers revealed that '
#  'the K456N troponin I variant increased the calcium sensitivity of force '
#  'generation by 2.5-fold.']
# - - Terms tagged of type 'mutant' - -
# ['k4', '56', 'n']
# - - - - - - Original text - - - - -
# ['Immunofluorescence staining revealed that the C278F FGFR2 variant localized '
#  'to the cell membrane at a higher density and for a longer duration than the '
#  'wild-type protein.']
# - - Terms tagged of type 'mutant' - -
# ['c2', '78', 'f']
# - - - - - - Original text - - - - -
# ['In our iron uptake experiments, cells expressing the C282Y HFE variant '
#  'failed to show the characteristic down-regulation of transferrin receptor '
#  'expression in response to high iron levels.']
# - - Terms tagged of type 'mutant' - -
# ['c2', '82', 'y']
# - - - - - - Original text - - - - -
# ['Immunoblotting of nuclear fractions showed a fragmented lamin A/C network in '
#  'cells from patients with the p.L320P variant, indicating a loss of nuclear '
#  'integrity.']
# - - Terms tagged of type 'mutant' - -
# ['p .', 'l3', '20', 'p']
# - - - - - - Original text - - - - -
# ['Pull-down assays with a cysteine-reactive probe demonstrated that the S295C '
#  'myotilin mutation forms intermolecular disulfide bonds, leading to the '
#  'formation of high-molecular-weight aggregates.']
# - - Terms tagged of type 'mutant' - -
# ['s2', '95', 'c']
# - - - - - - Original text - - - - -
# ['Liposome-based transport assays using the R402Q ABCA4 variant showed a 90% '
#  'reduction in the translocation of all-trans-retinal across the membrane.']
# - - Terms tagged of type 'mutant' - -
# ['r4', '02', 'q']
# - - - - - - Original text - - - - -
# ['Immunohistochemistry of spinal cord sections from transgenic mice expressing '
#  'the H46R SOD1 variant revealed extensive intracellular inclusions in motor '
#  'neurons, which were immunoreactive for ubiquitin.']
# - - Terms tagged of type 'mutant' - -
# ['h4', '6', 'r']
# - - - - - - Original text - - - - -
# ['In vitro enzyme kinetics demonstrated that the E258K lysosomal acid lipase '
#  'variant had a Vmax that was less than 5% of the wild-type enzyme, confirming '
#  'a severe loss-of-function.']
# - - Terms tagged of type 'mutant' - -
# ['e2', '58', 'k']
# - - - - - - Original text - - - - -
# ['Dye-transfer assays showed a complete failure of Lucifer yellow transfer '
#  'between cells expressing the M34T connexin 26 variant, indicating a loss of '
#  'gap junction function.']
# - - Terms tagged of type 'mutant' - -
# ['m3', '4', 't']
# - - - - - - Original text - - - - -
# ['Atomic force microscopy of extracellular matrix fibers from cells expressing '
#  'the K197R fibrillin-2 variant revealed an aberrant, disorganized microfibril '
#  'network.']
# - - Terms tagged of type 'mutant' - -
# ['k1', '97', 'r']
# - - - - - - Original text - - - - -
# ['A triple helix formation assay using purified L268P collagen type II '
#  "demonstrated a significant reduction in the protein's ability to form stable "
#  'triple helices.']
# - - Terms tagged of type 'mutant' - -
# ['l2', '68', 'p']
# - - - - - - Original text - - - - -
# ['Live-cell imaging of retrograde axonal transport in neurons with the P1213L '
#  'dynein heavy chain 1 variant showed a 75% decrease in the speed of cargo '
#  'movement toward the cell body.']
# - - Terms tagged of type 'mutant' - -
# ['p12', '13', 'l']
# - - - - - - Original text - - - - -
# ['Immunofluorescence of liver tissue from a patient with the R782W '
#  'α₁-antitrypsin variant revealed abundant inclusions of the protein within '
#  'hepatocytes, confirming its failure to be secreted.']
# - - Terms tagged of type 'mutant' - -
# ['r7', '82', 'w']
# - - - - - - Original text - - - - -
# ['The R136Q UCHL1 variant showed a 5-fold decrease in its isopeptidase '
#  'activity against a ubiquitinated substrate in a mass spectrometry-based '
#  'enzymatic assay.']
# - - Terms tagged of type 'mutant' - -
# ['r1', '36', 'q']
# - - - - - - Original text - - - - -
# ['In a fluorometric enzyme assay, the P270S glucocerebrosidase variant '
#  'exhibited only 40% of the catalytic activity observed with the wild-type '
#  'protein.']
# - - Terms tagged of type 'mutant' - -
# ['p27', '0', 's']
# - - - - - - Original text - - - - -
# ['Transmission electron microscopy of neuronal cultures expressing the A30P '
#  'α-synuclein variant showed the presence of abundant fibrillar aggregates, '
#  'similar to those found in Lewy bodies.']
# - - Terms tagged of type 'mutant' - -
# ['a3', '0', 'p']
# - - - - - - Original text - - - - -
# ['In our binding assays, the R46L PCSK9 variant demonstrated a 3-fold decrease '
#  'in its binding affinity for the LDL receptor, leading to a reduced rate of '
#  'receptor degradation.']
# - - Terms tagged of type 'mutant' - -
# ['r4', '6', 'l']
# - - - - - - Original text - - - - -
# ['Confocal microscopy of cells expressing the A152T tau variant revealed a '
#  'significant increase in the formation of puncta and filamentous structures, '
#  'suggesting enhanced aggregation.']
# - - Terms tagged of type 'mutant' - -
# ['a1', '52', 't']

# %%
gemini_gene = run_model(input_text=non_coding_variant_sentences)
filter_res(gemini_gene, "mutant")
# Out:
# - - - - - - Original text - - - - -
# ['Our massively parallel reporter assay (MPRA) data showed that the A>T '
#  "variant in the 3' UTR of the NOS1AP gene reduced the expression of a linked "
#  'fluorescent reporter by 40% in cardiomyocyte cells.']
# - - Terms tagged of type 'mutant' - -
# ['a > t']
# - - - - - - Original text - - - - -
# ['Sanger sequencing of the TERT promoter in melanoma samples identified two '
#  'recurrent non-coding variants, c.-124C>T and c.-146C>T, which were shown by '
#  'RT-qPCR to increase TERT mRNA expression by 15- and 20-fold, respectively.']
# - - Terms tagged of type 'mutant' - -
# ['c . - 124 c > t', 'c . - 146 c > t']
# - - - - - - Original text - - - - -
# ['Minigene splicing assays confirmed that the deep intronic variant '
#  'IVS21-12C>T in the CFTR gene leads to the creation of a cryptic splice site, '
#  'resulting in a mis-spliced transcript lacking exon 22.']
# - - Terms tagged of type 'mutant' - -
# ['iv', 's2', '1 - 12 c > t']
# - - - - - - Original text - - - - -
# ['Our electro mobility shift assay (EMSA) results showed that the C>G SNP in '
#  'the MDM2 promoter creates a novel high-affinity binding site for the SP1 '
#  'transcription factor, leading to increased MDM2 transcription.']
# - - Terms tagged of type 'mutant' - -
# ['c > g']
# - - - - - - Original text - - - - -
# ['Using CRISPR-Cas9 to introduce the rs7552554 variant in the promoter region '
#  'of the MYB oncogene, we observed a 3-fold increase in H3K27ac histone marks, '
#  'indicating enhanced enhancer activity.']
# - - Terms tagged of type 'mutant' - -
# ['rs7', '55', '255', '4']
# - - - - - - Original text - - - - -
# ['Allele-specific chromatin accessibility assays (ATAC-seq) revealed a loss of '
#  'an open chromatin region at the locus containing the rs12740374 variant, '
#  'suggesting a disruption of a transcription factor binding site.']
# - - Terms tagged of type 'mutant' - -
# ['rs', '127', '403', '74']
# - - - - - - Original text - - - - -
# ["The 3' UTR of the KRAS gene containing the rs61764370 variant was cloned "
#  'into a reporter plasmid, and subsequent luciferase assays showed a '
#  'significant reduction in luciferase activity, consistent with altered '
#  'miRNA-mediated repression.']
# - - Terms tagged of type 'mutant' - -
# ['61', '76', '43']
# - - - - - - Original text - - - - -
# ['Chr-RNA FISH experiments confirmed that the C>T mutation in the SHH limb '
#  'enhancer region failed to form a chromatin loop with the SHH promoter, '
#  'explaining the observed limb malformations.']
# - - Terms tagged of type 'mutant' - -
# ['c > t']
# - - - - - - Original text - - - - -
# ['We used CRISPR-based tiling scans to systematically test variants in the '
#  'LDLR promoter, finding that a specific A>C substitution reduced promoter '
#  'activity by 60%, a key finding for familial hypercholesterolemia.']
# - - Terms tagged of type 'mutant' - -
# ['a > c']
# - - - - - - Original text - - - - -
# ["A minigene assay showed that a single nucleotide variant (G>A) in the 5' "
#  'untranslated region of an unknown gene caused an increase in ribosome '
#  'readthrough and protein translation.']
# - - Terms tagged of type 'mutant' - -
# ['g > a']
# - - - - - - Original text - - - - -
# ['The C>G variant in the promoter of the CASP8 gene, located in a CpG island, '
#  'was shown by methylation-specific PCR to be associated with a complete loss '
#  'of DNA methylation and subsequent gene silencing.']
# - - Terms tagged of type 'mutant' - -
# ['c > g']
# - - - - - - Original text - - - - -
# ['In our chromatin accessibility assay, the A>G SNP in the FTO enhancer was '
#  'found to disrupt the binding of the ARID5B transcription factor, leading to '
#  'a downstream effect on gene regulation.']
# - - Terms tagged of type 'mutant' - -
# ['a > g']
# - - - - - - Original text - - - - -
# ['Our reporter assay demonstrated that the rs1403565 variant in the PITX2 '
#  'enhancer increased the transcriptional activity of a reporter construct by '
#  '30% in cardiac tissue cells.']
# - - Terms tagged of type 'mutant' - -
# ['rs', '140', '35', '65']

# %%
filter_res(gemini_gene, "protein")
# Out:
# - - - - - - Original text - - - - -
# ['Chromatin immunoprecipitation followed by sequencing (ChIP-seq) for the '
#  'transcription factor TCF7L2 revealed a loss of binding at the promoter of '
#  'the TCF7L2 gene in the presence of the rs7903146 risk allele.']
# - - Terms tagged of type 'protein' - -
# ['tcf', '7', 'l2', 'tcf', '7', 'l2']
# - - - - - - Original text - - - - -
# ['Our massively parallel reporter assay (MPRA) data showed that the A>T '
#  "variant in the 3' UTR of the NOS1AP gene reduced the expression of a linked "
#  'fluorescent reporter by 40% in cardiomyocyte cells.']
# - - Terms tagged of type 'protein' - -
# ['nos', '1a', 'p']
# - - - - - - Original text - - - - -
# ['Sanger sequencing of the TERT promoter in melanoma samples identified two '
#  'recurrent non-coding variants, c.-124C>T and c.-146C>T, which were shown by '
#  'RT-qPCR to increase TERT mRNA expression by 15- and 20-fold, respectively.']
# - - Terms tagged of type 'protein' - -
# ['tert', 'tert']
# - - - - - - Original text - - - - -
# ['A quantitative chromatin conformation capture (3C) assay demonstrated that '
#  'the rs9349379 SNP in a genomic insulator element disrupts the physical loop '
#  'connecting the ESR1 promoter to its upstream enhancer.']
# - - Terms tagged of type 'protein' - -
# ['esr1']
# - - - - - - Original text - - - - -
# ['Minigene splicing assays confirmed that the deep intronic variant '
#  'IVS21-12C>T in the CFTR gene leads to the creation of a cryptic splice site, '
#  'resulting in a mis-spliced transcript lacking exon 22.']
# - - Terms tagged of type 'protein' - -
# ['cftr']
# - - - - - - Original text - - - - -
# ['We performed allelic expression analysis on post-mortem brain tissue and '
#  'found that the rs12913832 SNP in the OCA2 gene enhancer was strongly '
#  'associated with a 50% decrease in its expression.']
# - - Terms tagged of type 'protein' - -
# ['oc', 'a2']
# - - - - - - Original text - - - - -
# ['Our electro mobility shift assay (EMSA) results showed that the C>G SNP in '
#  'the MDM2 promoter creates a novel high-affinity binding site for the SP1 '
#  'transcription factor, leading to increased MDM2 transcription.']
# - - Terms tagged of type 'protein' - -
# ['mdm2', 'sp1', 'mdm2']
# - - - - - - Original text - - - - -
# ['RNA-seq analysis of patient-derived lymphoblastoid cell lines with the '
#  "rs2201397 SNP in the TRIM59 3' UTR showed a significant upregulation of "
#  'TRIM59 transcript levels, which we hypothesize is due to altered microRNA '
#  'binding.']
# - - Terms tagged of type 'protein' - -
# ['trim', '59', 'trim', '59']
# - - - - - - Original text - - - - -
# ['Using CRISPR-Cas9 to introduce the rs7552554 variant in the promoter region '
#  'of the MYB oncogene, we observed a 3-fold increase in H3K27ac histone marks, '
#  'indicating enhanced enhancer activity.']
# - - Terms tagged of type 'protein' - -
# ['myb']
# - - - - - - Original text - - - - -
# ['The 5-kb deletion upstream of the SOX2 gene was found to completely abrogate '
#  'the expression of the gene in embryonic stem cells, suggesting the removal '
#  'of a critical long-range enhancer.']
# - - Terms tagged of type 'protein' - -
# ['sox2']
# - - - - - - Original text - - - - -
# ["Our Northern blot analysis revealed that the rs10825036 SNP in the 3' UTR of "
#  'the MIR-499 gene resulted in a mature miRNA transcript that was 50% less '
#  'abundant compared to the wild-type allele.']
# - - Terms tagged of type 'protein' - -
# ['mir - 499']
# - - - - - - Original text - - - - -
# ["The 3' UTR of the KRAS gene containing the rs61764370 variant was cloned "
#  'into a reporter plasmid, and subsequent luciferase assays showed a '
#  'significant reduction in luciferase activity, consistent with altered '
#  'miRNA-mediated repression.']
# - - Terms tagged of type 'protein' - -
# ['kras']
# - - - - - - Original text - - - - -
# ['Chr-RNA FISH experiments confirmed that the C>T mutation in the SHH limb '
#  'enhancer region failed to form a chromatin loop with the SHH promoter, '
#  'explaining the observed limb malformations.']
# - - Terms tagged of type 'protein' - -
# ['shh', 'shh']
# - - - - - - Original text - - - - -
# ['Reporter gene assays showed that the rs11603334 SNP in the ARAP1 promoter '
#  'led to a 2-fold upregulation of gene expression in pancreatic beta cells, '
#  'which was corroborated by decreased binding of PAX4 and PAX6 transcription '
#  'factors in EMSA.']
# - - Terms tagged of type 'protein' - -
# ['ara', 'p1', 'pax', '4', 'pax6']
# - - - - - - Original text - - - - -
# ['We used CRISPR-based tiling scans to systematically test variants in the '
#  'LDLR promoter, finding that a specific A>C substitution reduced promoter '
#  'activity by 60%, a key finding for familial hypercholesterolemia.']
# - - Terms tagged of type 'protein' - -
# ['ldlr']
# - - - - - - Original text - - - - -
# ['RNA-seq of patient tumor samples with the rs73183594 variant in the IRF4 '
#  'enhancer showed a significant increase in IRF4 mRNA expression levels, '
#  'suggesting a gain-of-function mechanism.']
# - - Terms tagged of type 'protein' - -
# ['irf', '4', 'irf', '4']
# - - - - - - Original text - - - - -
# ['Our allele-specific sequencing analysis of RNA from heterozygous individuals '
#  'demonstrated that the rs3796548 SNP, a non-coding variant, leads to a 3-fold '
#  'increase in the expression of the TULP3 gene.']
# - - Terms tagged of type 'protein' - -
# ['tul', 'p3']
# - - - - - - Original text - - - - -
# ['The deletion of an enhancer 150 kb upstream of the GATA6 gene was found to '
#  'cause a loss of GATA6 protein expression in pancreatic progenitor cells, as '
#  'confirmed by immunostaining.']
# - - Terms tagged of type 'protein' - -
# ['gata', '6', 'gata', '6']
# - - - - - - Original text - - - - -
# ['Quantitative real-time PCR (qRT-PCR) from patient fibroblasts with a deep '
#  'intronic variant in the IDUA gene revealed a reduced level of the fully '
#  'spliced transcript and an increase in a mis-spliced isoform.']
# - - Terms tagged of type 'protein' - -
# ['id', 'ua']
# - - - - - - Original text - - - - -
# ['The C>G variant in the promoter of the CASP8 gene, located in a CpG island, '
#  'was shown by methylation-specific PCR to be associated with a complete loss '
#  'of DNA methylation and subsequent gene silencing.']
# - - Terms tagged of type 'protein' - -
# ['casp', '8']
# - - - - - - Original text - - - - -
# ['In our chromatin accessibility assay, the A>G SNP in the FTO enhancer was '
#  'found to disrupt the binding of the ARID5B transcription factor, leading to '
#  'a downstream effect on gene regulation.']
# - - Terms tagged of type 'protein' - -
# ['fto', 'arid', '5b']
# - - - - - - Original text - - - - -
# ['Our reporter assay demonstrated that the rs1403565 variant in the PITX2 '
#  'enhancer increased the transcriptional activity of a reporter construct by '
#  '30% in cardiac tissue cells.']
# - - Terms tagged of type 'protein' - -
# ['pit', 'x2']
# - - - - - - Original text - - - - -
# ['The insertion of a SINE retrotransposon into the promoter of the FGFR2 gene '
#  "was shown by reporter assays to completely abolish the gene's promoter "
#  'activity in fibroblasts.']
# - - Terms tagged of type 'protein' - -
# ['fgfr2']

# %%
gemini_gene
# Out:
# [('Using a dual-luciferase reporter assay, we demonstrated that the SNP rs6983267, located in a long-range enhancer for the MYC oncogene, significantly increased reporter gene expression by 2.5-fold in colon cancer cell lines.',
#   [{'entity': 'dual - luciferase reporter assay',
#     'type': 'experimental_method'},
#    {'entity': 'rs', 'type': 'gene'},
#    {'entity': '69', 'type': 'gene'},
#    {'entity': '83', 'type': 'gene'},
#    {'entity': '267', 'type': 'gene'},
#    {'entity': 'long - range enhancer', 'type': 'structure_element'},
#    {'entity': 'myc', 'type': 'protein_type'}]),
#  ('Chromatin immunoprecipitation followed by sequencing (ChIP-seq) for the transcription factor TCF7L2 revealed a loss of binding at the promoter of the TCF7L2 gene in the presence of the rs7903146 risk allele.',
#   [{'entity': 'chromatin immunoprecipitation followed by sequencing',
#     'type': 'experimental_method'},
#    {'entity': 'chip - seq', 'type': 'experimental_method'},
#    {'entity': 'transcription factor', 'type': 'protein_type'},
#    {'entity': 'tcf', 'type': 'protein'},
#    {'entity': '7', 'type': 'protein'},
#    {'entity': 'l2', 'type': 'protein'},
#    {'entity': 'tcf', 'type': 'protein'},
#    {'entity': '7', 'type': 'protein'},
#    {'entity': 'l2', 'type': 'protein'}]),
#  ("Our massively parallel reporter assay (MPRA) data showed that the A>T variant in the 3' UTR of the NOS1AP gene reduced the expression of a linked fluorescent reporter by 40% in cardiomyocyte cells.",
#   [{'entity': 'massive', 'type': 'experimental_method'},
#    {'entity': 'ly parallel reporter assay', 'type': 'experimental_method'},
#    {'entity': 'mpr', 'type': 'experimental_method'},
#    {'entity': 'a', 'type': 'experimental_method'},
#    {'entity': 'a > t', 'type': 'mutant'},
#    {'entity': "3 ' utr", 'type': 'structure_element'},
#    {'entity': 'nos', 'type': 'protein'},
#    {'entity': '1a', 'type': 'protein'},
#    {'entity': 'p', 'type': 'protein'}]),
#  ('Sanger sequencing of the TERT promoter in melanoma samples identified two recurrent non-coding variants, c.-124C>T and c.-146C>T, which were shown by RT-qPCR to increase TERT mRNA expression by 15- and 20-fold, respectively.',
#   [{'entity': 'sanger sequencing', 'type': 'experimental_method'},
#    {'entity': 'tert', 'type': 'protein'},
#    {'entity': 'c . - 124 c > t', 'type': 'mutant'},
#    {'entity': 'c . - 146 c > t', 'type': 'mutant'},
#    {'entity': 'rt - qpcr', 'type': 'experimental_method'},
#    {'entity': 'tert', 'type': 'protein'}]),
#  ('A quantitative chromatin conformation capture (3C) assay demonstrated that the rs9349379 SNP in a genomic insulator element disrupts the physical loop connecting the ESR1 promoter to its upstream enhancer.',
#   [{'entity': 'quantitative chromatin conformation capture (',
#     'type': 'experimental_method'},
#    {'entity': '3c', 'type': 'experimental_method'},
#    {'entity': '93', 'type': 'gene'},
#    {'entity': '49', 'type': 'gene'},
#    {'entity': 'esr1', 'type': 'protein'},
#    {'entity': 'enhancer', 'type': 'structure_element'}]),
#  ('Minigene splicing assays confirmed that the deep intronic variant IVS21-12C>T in the CFTR gene leads to the creation of a cryptic splice site, resulting in a mis-spliced transcript lacking exon 22.',
#   [{'entity': 'mini', 'type': 'experimental_method'},
#    {'entity': 'gene splicing assays', 'type': 'experimental_method'},
#    {'entity': 'iv', 'type': 'mutant'},
#    {'entity': 's2', 'type': 'mutant'},
#    {'entity': '1 - 12 c > t', 'type': 'mutant'},
#    {'entity': 'cftr', 'type': 'protein'},
#    {'entity': 'cryptic', 'type': 'site'},
#    {'entity': 'splice site', 'type': 'site'},
#    {'entity': 'exon 22', 'type': 'structure_element'}]),
#  ('In a yeast-based screen, we found that a 15-bp deletion within the HBB promoter region completely abolished the binding of the GATA-1 transcription factor, consistent with the observed phenotype in beta-thalassemia patients.',
#   [{'entity': 'yeast - based screen', 'type': 'experimental_method'},
#    {'entity': '15', 'type': 'residue_range'},
#    {'entity': 'deletion', 'type': 'experimental_method'},
#    {'entity': 'hb', 'type': 'gene'},
#    {'entity': 'b', 'type': 'gene'},
#    {'entity': 'gata - 1 transcription factor', 'type': 'protein_type'}]),
#  ('We performed allelic expression analysis on post-mortem brain tissue and found that the rs12913832 SNP in the OCA2 gene enhancer was strongly associated with a 50% decrease in its expression.',
#   [{'entity': 'allelic expression analysis', 'type': 'experimental_method'},
#    {'entity': 'rs', 'type': 'gene'},
#    {'entity': '129', 'type': 'gene'},
#    {'entity': '138', 'type': 'gene'},
#    {'entity': '32', 'type': 'gene'},
#    {'entity': 'oc', 'type': 'protein'},
#    {'entity': 'a2', 'type': 'protein'}]),
#  ('Our electro mobility shift assay (EMSA) results showed that the C>G SNP in the MDM2 promoter creates a novel high-affinity binding site for the SP1 transcription factor, leading to increased MDM2 transcription.',
#   [{'entity': 'electro mobility shift assay', 'type': 'experimental_method'},
#    {'entity': 'emsa', 'type': 'experimental_method'},
#    {'entity': 'c > g', 'type': 'mutant'},
#    {'entity': 'mdm2', 'type': 'protein'},
#    {'entity': 'high - affinity binding site', 'type': 'site'},
#    {'entity': 'sp1', 'type': 'protein'},
#    {'entity': 'mdm2', 'type': 'protein'}]),
#  ("RNA-seq analysis of patient-derived lymphoblastoid cell lines with the rs2201397 SNP in the TRIM59 3' UTR showed a significant upregulation of TRIM59 transcript levels, which we hypothesize is due to altered microRNA binding.",
#   [{'entity': 'rna - seq', 'type': 'experimental_method'},
#    {'entity': '22', 'type': 'gene'},
#    {'entity': '01', 'type': 'gene'},
#    {'entity': '397', 'type': 'gene'},
#    {'entity': 'trim', 'type': 'protein'},
#    {'entity': '59', 'type': 'protein'},
#    {'entity': "3 ' utr", 'type': 'structure_element'},
#    {'entity': 'trim', 'type': 'protein'},
#    {'entity': '59', 'type': 'protein'},
#    {'entity': 'microrna', 'type': 'chemical'}]),
#  ('Using CRISPR-Cas9 to introduce the rs7552554 variant in the promoter region of the MYB oncogene, we observed a 3-fold increase in H3K27ac histone marks, indicating enhanced enhancer activity.',
#   [{'entity': 'crispr - cas9', 'type': 'experimental_method'},
#    {'entity': 'rs7', 'type': 'mutant'},
#    {'entity': '55', 'type': 'mutant'},
#    {'entity': '255', 'type': 'mutant'},
#    {'entity': '4', 'type': 'mutant'},
#    {'entity': 'myb', 'type': 'protein'}]),
#  ('The 5-kb deletion upstream of the SOX2 gene was found to completely abrogate the expression of the gene in embryonic stem cells, suggesting the removal of a critical long-range enhancer.',
#   [{'entity': 'deletion', 'type': 'experimental_method'},
#    {'entity': 'sox2', 'type': 'protein'}]),
#  ('In a high-throughput screen, we identified an A>G variant in the promoter of a lncRNA that significantly decreased its transcription by 75% in a disease-relevant cell model.',
#   [{'entity': 'high - throughput screen', 'type': 'experimental_method'},
#    {'entity': 'a > g', 'type': 'residue_name'},
#    {'entity': 'lncrna', 'type': 'protein_type'}]),
#  ("Our Northern blot analysis revealed that the rs10825036 SNP in the 3' UTR of the MIR-499 gene resulted in a mature miRNA transcript that was 50% less abundant compared to the wild-type allele.",
#   [{'entity': 'northern blot analysis', 'type': 'experimental_method'},
#    {'entity': 'rs10', 'type': 'gene'},
#    {'entity': '82', 'type': 'gene'},
#    {'entity': '50', 'type': 'gene'},
#    {'entity': '36', 'type': 'gene'},
#    {'entity': "3 ' utr", 'type': 'structure_element'},
#    {'entity': 'mir - 499', 'type': 'protein'},
#    {'entity': 'mirna', 'type': 'chemical'},
#    {'entity': 'wild - type', 'type': 'protein_state'}]),
#  ('Allele-specific chromatin accessibility assays (ATAC-seq) revealed a loss of an open chromatin region at the locus containing the rs12740374 variant, suggesting a disruption of a transcription factor binding site.',
#   [{'entity': 'allele - specific chromatin accessibility assays',
#     'type': 'experimental_method'},
#    {'entity': 'ata', 'type': 'experimental_method'},
#    {'entity': 'c - seq', 'type': 'experimental_method'},
#    {'entity': 'rs', 'type': 'mutant'},
#    {'entity': '127', 'type': 'mutant'},
#    {'entity': '403', 'type': 'mutant'},
#    {'entity': '74', 'type': 'mutant'},
#    {'entity': 'transcription factor binding site', 'type': 'site'}]),
#  ("The 3' UTR of the KRAS gene containing the rs61764370 variant was cloned into a reporter plasmid, and subsequent luciferase assays showed a significant reduction in luciferase activity, consistent with altered miRNA-mediated repression.",
#   [{'entity': "3 ' utr", 'type': 'structure_element'},
#    {'entity': 'kras', 'type': 'protein'},
#    {'entity': '61', 'type': 'mutant'},
#    {'entity': '76', 'type': 'mutant'},
#    {'entity': '43', 'type': 'mutant'},
#    {'entity': 'luciferase assays', 'type': 'experimental_method'},
#    {'entity': 'mirna', 'type': 'chemical'}]),
#  ('Chr-RNA FISH experiments confirmed that the C>T mutation in the SHH limb enhancer region failed to form a chromatin loop with the SHH promoter, explaining the observed limb malformations.',
#   [{'entity': 'chr - rna fish', 'type': 'experimental_method'},
#    {'entity': 'c > t', 'type': 'mutant'},
#    {'entity': 'shh', 'type': 'protein'},
#    {'entity': 'shh', 'type': 'protein'}]),
#  ('Reporter gene assays showed that the rs11603334 SNP in the ARAP1 promoter led to a 2-fold upregulation of gene expression in pancreatic beta cells, which was corroborated by decreased binding of PAX4 and PAX6 transcription factors in EMSA.',
#   [{'entity': 'reporter gene assays', 'type': 'experimental_method'},
#    {'entity': 'rs', 'type': 'gene'},
#    {'entity': '116', 'type': 'gene'},
#    {'entity': '03', 'type': 'gene'},
#    {'entity': '33', 'type': 'gene'},
#    {'entity': '4', 'type': 'gene'},
#    {'entity': 'ara', 'type': 'protein'},
#    {'entity': 'p1', 'type': 'protein'},
#    {'entity': 'pax', 'type': 'protein'},
#    {'entity': '4', 'type': 'protein'},
#    {'entity': 'pax6', 'type': 'protein'},
#    {'entity': 'emsa', 'type': 'experimental_method'}]),
#  ('We used CRISPR-based tiling scans to systematically test variants in the LDLR promoter, finding that a specific A>C substitution reduced promoter activity by 60%, a key finding for familial hypercholesterolemia.',
#   [{'entity': 'crispr - based til ing scans', 'type': 'experimental_method'},
#    {'entity': 'ldlr', 'type': 'protein'},
#    {'entity': 'a > c', 'type': 'mutant'}]),
#  ('RNA-seq of patient tumor samples with the rs73183594 variant in the IRF4 enhancer showed a significant increase in IRF4 mRNA expression levels, suggesting a gain-of-function mechanism.',
#   [{'entity': 'rna - seq', 'type': 'experimental_method'},
#    {'entity': 'irf', 'type': 'protein'},
#    {'entity': '4', 'type': 'protein'},
#    {'entity': 'irf', 'type': 'protein'},
#    {'entity': '4', 'type': 'protein'}]),
#  ('Our allele-specific sequencing analysis of RNA from heterozygous individuals demonstrated that the rs3796548 SNP, a non-coding variant, leads to a 3-fold increase in the expression of the TULP3 gene.',
#   [{'entity': 'allele - specific sequencing analysis',
#     'type': 'experimental_method'},
#    {'entity': 'rna', 'type': 'chemical'},
#    {'entity': 'rs', 'type': 'gene'},
#    {'entity': '37', 'type': 'gene'},
#    {'entity': '96', 'type': 'gene'},
#    {'entity': '54', 'type': 'gene'},
#    {'entity': '8', 'type': 'gene'},
#    {'entity': 'tul', 'type': 'protein'},
#    {'entity': 'p3', 'type': 'protein'}]),
#  ('The deletion of an enhancer 150 kb upstream of the GATA6 gene was found to cause a loss of GATA6 protein expression in pancreatic progenitor cells, as confirmed by immunostaining.',
#   [{'entity': 'deletion of', 'type': 'experimental_method'},
#    {'entity': 'enhancer', 'type': 'structure_element'},
#    {'entity': 'gata', 'type': 'protein'},
#    {'entity': '6', 'type': 'protein'},
#    {'entity': 'gata', 'type': 'protein'},
#    {'entity': '6', 'type': 'protein'},
#    {'entity': 'immunostaining', 'type': 'experimental_method'}]),
#  ('Using a high-resolution 4C-seq, we mapped the chromosomal interactions of the genomic region containing a non-coding variant, revealing the creation of a novel chromatin loop between a distant enhancer and an oncogene.',
#   [{'entity': '4c - seq', 'type': 'experimental_method'}]),
#  ("A minigene assay showed that a single nucleotide variant (G>A) in the 5' untranslated region of an unknown gene caused an increase in ribosome readthrough and protein translation.",
#   [{'entity': 'mini', 'type': 'experimental_method'},
#    {'entity': 'gene assay', 'type': 'experimental_method'},
#    {'entity': 'g > a', 'type': 'mutant'},
#    {'entity': "5 ' untranslated region", 'type': 'structure_element'}]),
#  ('Quantitative real-time PCR (qRT-PCR) from patient fibroblasts with a deep intronic variant in the IDUA gene revealed a reduced level of the fully spliced transcript and an increase in a mis-spliced isoform.',
#   [{'entity': 'quantitative real - time pcr', 'type': 'experimental_method'},
#    {'entity': 'qrt - pcr', 'type': 'experimental_method'},
#    {'entity': 'id', 'type': 'protein'},
#    {'entity': 'ua', 'type': 'protein'},
#    {'entity': 'fully spliced', 'type': 'protein_state'}]),
#  ('The C>G variant in the promoter of the CASP8 gene, located in a CpG island, was shown by methylation-specific PCR to be associated with a complete loss of DNA methylation and subsequent gene silencing.',
#   [{'entity': 'c > g', 'type': 'mutant'},
#    {'entity': 'casp', 'type': 'protein'},
#    {'entity': '8', 'type': 'protein'},
#    {'entity': 'cpg island', 'type': 'site'},
#    {'entity': 'methylation - specific pcr', 'type': 'experimental_method'}]),
#  ('In our chromatin accessibility assay, the A>G SNP in the FTO enhancer was found to disrupt the binding of the ARID5B transcription factor, leading to a downstream effect on gene regulation.',
#   [{'entity': 'chromatin accessibility assay', 'type': 'experimental_method'},
#    {'entity': 'a > g', 'type': 'mutant'},
#    {'entity': 'fto', 'type': 'protein'},
#    {'entity': 'arid', 'type': 'protein'},
#    {'entity': '5b', 'type': 'protein'}]),
#  ('Our reporter assay demonstrated that the rs1403565 variant in the PITX2 enhancer increased the transcriptional activity of a reporter construct by 30% in cardiac tissue cells.',
#   [{'entity': 'reporter assay', 'type': 'experimental_method'},
#    {'entity': 'rs', 'type': 'mutant'},
#    {'entity': '140', 'type': 'mutant'},
#    {'entity': '35', 'type': 'mutant'},
#    {'entity': '65', 'type': 'mutant'},
#    {'entity': 'pit', 'type': 'protein'},
#    {'entity': 'x2', 'type': 'protein'}]),
#  ("The insertion of a SINE retrotransposon into the promoter of the FGFR2 gene was shown by reporter assays to completely abolish the gene's promoter activity in fibroblasts.",
#   [{'entity': 'sine retrotranspos on', 'type': 'protein_type'},
#    {'entity': 'fgfr2', 'type': 'protein'},
#    {'entity': 'reporter assays', 'type': 'experimental_method'}]),
#  ('CRISPR activation experiments using a sgRNA targeting the promoter region of a lncRNA confirmed that a non-coding variant within this region was responsible for a significant reduction in gene expression.',
#   [{'entity': 'crispr activation experiments', 'type': 'experimental_method'},
#    {'entity': 'sgrna', 'type': 'chemical'},
#    {'entity': 'lncrna', 'type': 'protein_type'}])]

# %% [markdown]
# ### AE classifier - not worth chasing

# %%
from transformers import AutoTokenizer, AutoModelForSequenceClassification

# This model is a classifier: AE is / is not present in text
tokenizer = AutoTokenizer.from_pretrained("jocforero/longformer-adverse-event-classifier")
ae_model = AutoModelForSequenceClassification.from_pretrained("jocforero/longformer-adverse-event-classifier")
# Out:
# tokenizer_config.json: 0.00B [00:00, ?B/s]
# vocab.json: 0.00B [00:00, ?B/s]
# merges.txt: 0.00B [00:00, ?B/s]
# tokenizer.json: 0.00B [00:00, ?B/s]
# special_tokens_map.json:   0%|          | 0.00/964 [00:00<?, ?B/s]
# config.json:   0%|          | 0.00/961 [00:00<?, ?B/s]
# model.safetensors:   0%|          | 0.00/595M [00:00<?, ?B/s]

# %%
gemini_ae_egs = [
    "Gastrointestinal bleeding occurred in two patients receiving the active treatment."
    "One participant in the control group experienced anaphylactic shock requiring immediate medical intervention.",
    "The most frequently reported adverse event was mild-to-moderate headache, observed in 15% of the study population.",
    "Three cases of acute renal failure were documented, leading to discontinuation of the study drug.",
    "A dose-dependent increase in serum transaminases was observed in a subset of participants.",
    "The device's implantation was associated with local tissue necrosis in 5% of subjects.",
    "A single instance of pulmonary embolism was reported in a patient with no prior history of thrombotic events.",
    "Patients on the higher dose of the compound exhibited a significant increase in systolic blood pressure.",
    "Study withdrawal was attributed to unmanageable nausea and vomiting in four subjects.",
    "One participant developed a maculopapular rash that was determined to be a hypersensitivity reaction to the study medication.",
    "This is a test, nothing to see here.", # Should be false, completely out of context
    "The study was conducted in a double-blind, placebo-controlled manner.", # Should be false, in context but 0 AE
    "An adverse event of headache was reported." # Can't get much more obvious a statement
    ]

# %%
import torch

batch_size=4
max_length=512

all_results = []
    
# Process in batches
for i in range(0, len(gemini_ae_egs), batch_size):
    # Get the current batch
    batch_texts = gemini_ae_egs[i:i + batch_size]
    
    # Tokenize and pass to model
    inputs = tokenizer(batch_texts, return_tensors="pt", padding=True, truncation=True, max_length=max_length)
    print(batch_texts)
    with torch.no_grad():
        outputs = ae_model(**inputs)

    # Decode predictions and configure id to label map
    predictions = torch.argmax(outputs.logits, dim=1)
    print(predictions)
    id_to_label = ae_model.config.id2label
    print(id_to_label)
# Out:
# ['Gastrointestinal bleeding occurred in two patients receiving the active treatment.One participant in the control group experienced anaphylactic shock requiring immediate medical intervention.', 'The most frequently reported adverse event was mild-to-moderate headache, observed in 15% of the study population.', 'Three cases of acute renal failure were documented, leading to discontinuation of the study drug.', 'A dose-dependent increase in serum transaminases was observed in a subset of participants.']
# tensor([0, 0, 0, 0])
# {0: 'LABEL_0', 1: 'LABEL_1'}
# ["The device's implantation was associated with local tissue necrosis in 5% of subjects.", 'A single instance of pulmonary embolism was reported in a patient with no prior history of thrombotic events.', 'Patients on the higher dose of the compound exhibited a significant increase in systolic blood pressure.', 'Study withdrawal was attributed to unmanageable nausea and vomiting in four subjects.']
# tensor([0, 0, 0, 0])
# {0: 'LABEL_0', 1: 'LABEL_1'}
# ['One participant developed a maculopapular rash that was determined to be a hypersensitivity reaction to the study medication.', 'This is a test, nothing to see here.', 'The study was conducted in a double-blind, placebo-controlled manner.', 'An adverse event of headache was reported.']
# tensor([0, 0, 0, 0])
# {0: 'LABEL_0', 1: 'LABEL_1'}
